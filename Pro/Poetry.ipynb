# %%
# 检查 Arrow 数据集的列名
from datasets import load_from_disk

dataset_path = r"D:/桌面/DL/Pro/poetry_foundation"
dataset = load_from_disk(dataset_path)
train_dataset = dataset["train"]

print(train_dataset.column_names)  # 查看真实列名
print(train_dataset[0])  # 查看第一条记录
# Out:
# ['Unnamed: 0', 'Title', 'Poem', 'Poet', 'Tags']
# {'Unnamed: 0': 0, 'Title': '\r\r\n                    Objects Used to Prop Open a Window\r\r\n                ', 'Poem': "\r\r\nDog bone, stapler,\r\r\ncribbage board, garlic press\r\r\n     because this window is loose—lacks\r\r\nsuction, lacks grip.\r\r\nBungee cord, bootstrap,\r\r\ndog leash, leather belt\r\r\n     because this window had sash cords.\r\r\nThey frayed. They broke.\r\r\nFeather duster, thatch of straw, empty\r\r\nbottle of Elmer's glue\r\r\n     because this window is loud—its hinges clack\r\r\nopen, clack shut.\r\r\nStuffed bear, baby blanket,\r\r\nsingle crib newel\r\r\n     because this window is split. It's dividing\r\r\nin two.\r\r\nVelvet moss, sagebrush,\r\r\nwillow branch, robin's wing\r\r\n     because this window, it's pane-less. It's only\r\r\na frame of air.\r\r\n", 'Poet': 'Michelle Menting', 'Tags': None}

# %%
from datasets import load_from_disk
import json
from pathlib import Path
from collections import Counter
import random

# -----------------------------
# 配置路径
# -----------------------------
dataset_path = r"D:/桌面/DL/Pro/poetry_foundation"
dataset = load_from_disk(dataset_path)["train"]
output_path = Path("D:/桌面/DL/Pro/poetry_sft_enhanced.jsonl")

# -----------------------------
# 清洗文本函数
# -----------------------------
def clean(text):
    if text is None:
        return ""
    return text.replace("\r", "").strip()

# -----------------------------
# 统计每个作者的诗歌数量
# -----------------------------
author_counter = Counter()
for item in dataset:
    poet = clean(item.get("Poet", "Unknown"))
    author_counter[poet] += 1

# -----------------------------
# 灵活生成 user prompt（增强版）
# -----------------------------
def make_user_prompt(title, tags, poet):
    """
    增强版：
    - 随机选择模板：只风格、只主题、风格+主题
    - 对诗歌数 < 10 的作者，不生成风格 prompt
    """
    prompt_types = []

    # 判断是否可以生成风格相关 prompt
    if poet and author_counter[poet] >= 10:
        prompt_types.append("style")
        prompt_types.append("style+theme")  # 风格+主题

    if tags or title:
        prompt_types.append("theme_only")  # 只指定主题

    if not prompt_types:
        prompt_types.append("theme_only")  # 兜底

    # 随机选择一种模板
    choice = random.choice(prompt_types)

    if choice == "style":
        return f"Write a poem in the style of {poet}."
    elif choice == "theme_only":
        theme = tags if tags else title
        return f"Write a poem using the theme: {theme}."
    elif choice == "style+theme":
        theme = tags if tags else title
        return f"Write a poem using the theme: {theme}, in the style of {poet}."
    else:
        return f"Write a poem using the theme: {title}."

# -----------------------------
# 写入增强版 JSONL
# -----------------------------
with open(output_path, "w", encoding="utf-8") as f:
    for item in dataset:
        title = clean(item.get("Title", ""))
        poem = clean(item.get("Poem", ""))
        poet = clean(item.get("Poet", ""))
        tags = clean(item.get("Tags")) if item.get("Tags") else ""

        user_prompt = make_user_prompt(title, tags, poet)

        record = {
            "messages": [
                {"role": "user", "content": user_prompt},
                {"role": "assistant", "content": poem}
            ]
        }
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

print(f"转换完成！共 {len(dataset)} 条，输出到 {output_path}")
# Out:
# 转换完成！共 13854 条，输出到 D:\桌面\DL\Pro\poetry_sft_enhanced.jsonl

# %%
import json
from pathlib import Path

# -----------------------------
# 配置路径
# -----------------------------
input_path = Path("D:/桌面/DL/Pro/gutenberg-poetry-v001.ndjson")
output_path = Path("D:/桌面/DL/Pro/gutenberg_poem_line_sft.jsonl")

# -----------------------------
# Step 1: 定义过滤规则
# -----------------------------
def is_poem_line(line: str) -> bool:
    """
    改进过滤规则：
    - 排除明显前言/注释
    - 限制单行长度
    - 排除说明性开头
    - 单行单词数少于15
    """
    skip_words = ["copyright", "collected by", "chapter", "gutenberg", "introduction"]
    skip_phrases = ["is based on", "legends and stories", "collected by", "notes on the text"]
    
    lower_line = line.lower()
    
    # 含 skip_words
    if any(word in lower_line for word in skip_words):
        return False
    
    # 含 skip_phrases
    if any(phrase in lower_line for phrase in skip_phrases):
        return False
    
    # 太长的行（通常不是诗句）
    if len(line) > 70:
        return False
    
    # 单词数限制
    if len(line.split()) >= 15:
        return False
    
    return True

# -----------------------------
# Step 2: 读取每行并生成 SFT 样本
# -----------------------------
with open(input_path, "r", encoding="utf-8") as fin, \
     open(output_path, "w", encoding="utf-8") as fout:
    
    for line in fin:
        if not line.strip():
            continue
        item = json.loads(line)
        s = item.get("s", "").strip()
        if not s:
            continue
        if not is_poem_line(s):
            continue
        
        # 每行诗句生成一条 SFT 样本
        sft_record = {
            "messages": [
                {
                    "role": "user",
                    "content": "Write a poem in the same style as the following example."
                },
                {
                    "role": "assistant",
                    "content": s
                }
            ]
        }
        
        fout.write(json.dumps(sft_record, ensure_ascii=False) + "\n")

print(f"✔ 已生成每行诗句风格学习 SFT JSONL: {output_path}")
# Out:
# ✔ 已生成每行诗句风格学习 SFT JSONL: D:\桌面\DL\Pro\gutenberg_poem_line_sft.jsonl

# %%
from datasets import load_from_disk
from collections import Counter

# -----------------------------
# 加载数据集
# -----------------------------
dataset_path = r"D:/桌面/DL/Pro/poetry_foundation"
dataset = load_from_disk(dataset_path)
train_dataset = dataset["train"]

# -----------------------------
# 统计作者信息
# -----------------------------
author_counter = Counter()

for record in train_dataset:
    author = record.get("Poet", "Unknown")  # 根据真实列名调整
    author_counter[author] += 1

unique_authors = len(author_counter)

# -----------------------------
# 输出结果
# -----------------------------
total_poems = len(train_dataset)
print(f"转换完成！共 {total_poems} 条记录")
print(f"唯一作者数: {unique_authors}")

print("\n前 10 位诗歌最多的作者:")
for author, count in author_counter.most_common(10):
    print(f"{author}: {count} 首")
# Out:
# 转换完成！共 13854 条记录
# 唯一作者数: 3128
#
# 前 10 位诗歌最多的作者:
# William Shakespeare: 85 首
# Alfred, Lord Tennyson: 73 首
# Emily Dickinson: 51 首
# William Wordsworth: 51 首
# Rae Armantrout: 49 首
# John Ashbery: 42 首
# Yusef Komunyakaa: 42 首
# William Butler Yeats: 41 首
# John Donne: 38 首
# Robert Browning: 35 首
# Percy Bysshe Shelley: 35 首
# Walt Whitman: 35 首
# Algernon Charles Swinburne: 35 首
# Kay Ryan: 34 首
# John Milton: 33 首
# William Blake: 33 首
# Edmund Spenser: 33 首
# Samuel Menashe: 33 首
# W. S. Merwin: 32 首
# Edward Thomas: 32 首
# Thomas Hardy: 32 首
# Henry Wadsworth Longfellow: 32 首
# W. S. Di Piero: 32 首
# Samuel Taylor Coleridge: 32 首
# Edgar Lee Masters: 31 首
# Edna St. Vincent Millay: 29 首
# Robert Frost: 28 首
# Wallace Stevens: 28 首
# Dean Young: 28 首
# Jane Hirshfield: 28 首
# Billy Collins: 27 首
# William Carlos Williams: 27 首
# Kahlil Gibran: 27 首
# Sir Philip Sidney: 27 首
# George Herbert: 27 首
# Amy Lowell: 27 首
# Matthew Arnold: 27 首
# Frank Stanford: 27 首
# Elizabeth Barrett Browning: 26 首
# Carl Sandburg: 26 首
# Ben Jonson: 26 首
# Naomi Shihab Nye: 25 首
# Sir  Thomas Wyatt: 25 首
# A. E. Stallings: 25 首
# Rita Dove: 24 首
# Lucille Clifton: 24 首
# D. A. Powell: 24 首
# Gerald Stern: 24 首
# Charles Reznikoff: 24 首
# Ange Mlinko: 24 首
# Christina Rossetti: 23 首
# Robert Creeley: 23 首
# Tom Sleigh: 23 首
# Gwendolyn Brooks: 23 首
# Rudyard Kipling: 23 首
# Howard Nemerov: 23 首
# John Keats: 23 首
# Andrew Marvell: 23 首
# Robert Herrick: 23 首
# Mother Goose: 23 首
# James Tate: 22 首
# Christian Wiman: 22 首
# Randall Mann: 22 首
# Dante Gabriel Rossetti: 22 首
# D. H. Lawrence: 21 首
# Wendy Videlock: 21 首
# Lorine Niedecker: 21 首
# Siegfried Sassoon: 21 首
# James Galvin: 21 首
# Gottfried Benn: 21 首
# Roddy Lumsden: 21 首
# Brenda Hillman: 20 首
# Juan Felipe Herrera: 20 首
# Louise Bogan: 20 首
# Carl Phillips: 20 首
# Ezra Pound: 20 首
# Stanley Moss: 20 首
# Herman Melville: 20 首
# Li-Young Lee: 20 首
# Alice Notley: 20 首
# Brenda Shaughnessy: 20 首
# Denise Levertov: 20 首
# William Matthews: 20 首
# Stephen Dobyns: 20 首
# George Meredith: 20 首
# Langston Hughes: 19 首
# Muriel Rukeyser: 19 首
# Thomas Bastard: 19 首
# Charles Simic: 19 首
# Gertrude Stein: 19 首
# Heather McHugh: 19 首
# Donald Revell: 19 首
# Gerard Manley Hopkins: 19 首
# Franz Wright: 19 首
# Alexander Pope: 19 首
# Carolyn Kizer: 18 首
# J. Patrick Lewis: 18 首
# Bob Hicok: 18 首
# Edgar Allan Poe: 18 首
# D. Nurkse: 18 首
# Alicia Ostriker: 18 首
# Dana Gioia: 18 首
# Ilya Kaminsky: 18 首
# Atsuro Riley: 18 首
# Sandra McPherson: 18 首
# Alan R. Shapiro: 18 首
# Louise Glück: 18 首
# Robert Burns: 18 首
# John Dryden: 18 首
# Ted Kooser: 17 首
# Tracy K. Smith: 17 首
# David Ferry: 17 首
# Gary Snyder: 17 首
# Martín Espada: 17 首
# Robert W. Service: 17 首
# Tony Hoagland: 17 首
# C. Dale Young: 17 首
# C. D. Wright: 17 首
# Elaine Equi: 17 首
# Marie Ponsot: 17 首
# Aimee Nezhukumatathil: 16 首
# John Koethe: 16 首
# Michael Ryan: 16 首
# Peter Balakian: 16 首
# Harmony Holiday: 16 首
# Lord Byron (George Gordon): 16 首
# Henry Timrod: 16 首
# Lyn Hejinian: 16 首
# George Oppen: 16 首
# Sara Teasdale: 16 首
# Mary Jo Bang: 16 首
# William E. Stafford: 16 首
# Jay Wright: 16 首
# Alberto Ríos: 16 首
# Derek Mahon: 16 首
# Robin Blaser: 16 首
# Scott Cairns: 16 首
# Mary Ruefle: 16 首
# A. F. Moritz: 16 首
# Josephine Miles: 16 首
# W. D. Snodgrass: 16 首
# Ralph Waldo Emerson: 16 首
# Louise Imogen Guiney: 16 首
# James Wright: 16 首
# Elizabeth Alexander: 16 首
# Howard Moss: 16 首
# Marge Piercy: 15 首
# Natasha Trethewey: 15 首
# Samuel Daniel: 15 首
# A. E. Housman: 15 首
# A. R. Ammons: 15 首
# Ray Gonzalez: 15 首
# Eileen Myles: 15 首
# Michael Palmer: 15 首
# Ted Berrigan: 15 首
# Forrest Gander: 15 首
# Stevie Smith: 15 首
# Paisley Rekdal: 15 首
# Fanny Howe: 15 首
# Ron Padgett: 15 首
# Toi Derricotte: 15 首
# Frank Lima: 15 首
# Nikki Giovanni: 15 首
# Marianne Boruch: 15 首
# Philip Levine: 15 首
# Albert Goldbarth: 15 首
# Lawrence Ferlinghetti: 15 首
# Hayden Carruth: 15 首
# John Fuller: 15 首
# Robert Hass: 14 首
# Michael Drayton: 14 首
# June Jordan: 14 首
# Ed Roberson: 14 首
# Linda Pastan: 14 首
# Bernadette Mayer: 14 首
# Melvin B. Tolson: 14 首
# Wilfred Owen: 14 首
# Gail Mazur: 14 首
# Frank O'Hara: 14 首
# Nick Flynn: 14 首
# Ross Gay: 14 首
# Chase Twichell: 14 首
# Carol Frost: 14 首
# Ruth Stone: 14 首
# Louis Simpson: 14 首
# Trumbull Stickney: 14 首
# John Ciardi: 14 首
# Emily Brontë: 14 首
# Jack Prelutsky: 14 首
# Geoffrey Hill: 14 首
# Charles Bukowski: 14 首
# Joy Harjo: 13 首
# Jorie Graham: 13 首
# Mark Halliday: 13 首
# William Cullen Bryant: 13 首
# Linda Gregerson: 13 首
# Marilyn Nelson: 13 首
# Ivor Gurney: 13 首
# Robert Graves: 13 首
# H. D.: 13 首
# Danez Smith: 13 首
# Cornelius Eady: 13 首
# Sharon Olds: 13 首
# David Rivard: 13 首
# Mary Karr: 13 首
# Sarah Lindsay: 13 首
# Larry Levis: 13 首
# Eleanor Wilner: 13 首
# Gary Soto: 13 首
# Louis Untermeyer: 13 首
# Richard Crashaw: 13 首
# Paul Laurence Dunbar: 13 首
# Walter Savage Landor: 13 首
# Philip Larkin: 13 首
# Czeslaw Milosz: 13 首
# Norman Dubie: 13 首
# Dorianne Laux: 12 首
# Harryette Mullen: 12 首
# Joanna Klink: 12 首
# Terrance Hayes: 12 首
# Evie Shockley: 12 首
# Julian Talamantez Brolaski: 12 首
# Fady Joudah: 12 首
# Vachel Lindsay: 12 首
# Charles Wright: 12 首
# Robert Duncan: 12 首
# Keith Waldrop: 12 首
# Matthew Rohrer: 12 首
# Dorothea Lasky: 12 首
# Stephen Edgar: 12 首
# Eavan Boland: 12 首
# Claudia Emerson: 12 首
# Rabindranath Tagore: 12 首
# Jane Kenyon: 12 首
# Joseph Brodsky: 12 首
# Sir Walter Ralegh: 12 首
# Isaac Rosenberg: 12 首
# Kevin Young: 12 首
# Sylvia Plath: 12 首
# Rachel Sherwood: 12 首
# Susan Stewart: 12 首
# J. Allyn Rosser: 12 首
# Camille T. Dungy: 12 首
# Linda Bierds: 12 首
# Reginald Gibbons: 12 首
# James K. Baxter: 12 首
# Matthew Sweeney: 12 首
# Eliza Griswold: 12 首
# Devin Johnston: 12 首
# David Baker: 12 首
# Robert Pinsky: 12 首
# Hailey Leithauser: 12 首
# Delmore Schwartz: 12 首
# Michael S. Harper: 12 首
# Richard Wilbur: 12 首
# William Meredith: 12 首
# T. S. Eliot: 12 首
# Edgar Albert Guest: 12 首
# Knight of the White Elephant of Burmah William McGonagall: 12 首
# Eva Gore-Booth: 12 首
# Margaret Atwood: 12 首
# Léonie Adams: 12 首
# George Seferis: 12 首
# Heid E. Erdrich: 11 首
# Kim Addonizio: 11 首
# Mina Loy: 11 首
# Dunya Mikhail: 11 首
# Cedar Sigo: 11 首
# Matthea Harvey: 11 首
# Etheridge Knight: 11 首
# Jean Toomer: 11 首
# Joyce Sutphen: 11 首
# David St. John: 11 首
# Stephen Sandy: 11 首
# Tim Dlugos: 11 首
# Charlotte Mew: 11 首
# Alice Oswald: 11 首
# Anne Waldman: 11 首
# Katie Peterson: 11 首
# Kenneth Koch: 11 首
# Carl Rakosi: 11 首
# Alice B. Fogel: 11 首
# Alice Fulton: 11 首
# Dan Beachy-Quick: 11 首
# Anne Winters: 11 首
# May Swenson: 11 首
# Carolyn Forché: 11 首
# Todd Boss: 11 首
# Nate Klug: 11 首
# Jessica Greenbaum: 11 首
# James Laughlin: 11 首
# Tom Clark: 11 首
# Thomas Lux: 11 首
# Stephen Dunn: 11 首
# Ben Belitt: 11 首
# Galway Kinnell: 11 首
# James L. Dickey: 11 首
# J. V. Cunningham: 11 首
# Karl Shapiro: 11 首
# Archibald MacLeish: 11 首
# Donald Hall: 11 首
# Aphra Behn: 11 首
# Anne Bradstreet: 11 首
# Thomas Campion: 11 首
# Edwin Arlington Robinson: 11 首
# Henry Vaughan: 11 首
# John Greenleaf Whittier: 11 首
# Marvin Bell: 11 首
# Hilaire Belloc: 11 首
# R. T. Smith: 11 首
# Linda Gregg: 11 首
# Jimmy Santiago Baca: 11 首
# Yvor Winters: 11 首
# Edwin Markham: 11 首
# Gregory Djanikian: 11 首
# Anne Stevenson: 11 首
# Diane Glancy: 11 首
# Quan Barry: 10 首
# Aracelis Girmay: 10 首
# Thomas Centolella: 10 首
# Wesley McNair: 10 首
# Alli Warren: 10 首
# Wendy Xu: 10 首
# Amy Gerstler: 10 首
# Megan Snyder-Camp: 10 首
# Stephanie Burt: 10 首
# Meena Alexander: 10 首
# Charles Bernstein: 10 首
# Roberto Harrison: 10 首
# E. E. Cummings: 10 首
# Ntozake Shange: 10 首
# Barbara Guest: 10 首
# Rupert Brooke: 10 首
# Bill Berkson: 10 首
# Will Alexander: 10 首
# Arthur Rimbaud: 10 首
# Alan Dugan: 10 首
# Adonis: 10 首
# David Yezzi: 10 首
# Farnoosh Fathi: 10 首
# Ella Wheeler Wilcox: 10 首
# Maggie Dietz: 10 首
# Paul Violi: 10 首
# Jericho Brown: 10 首
# CAConrad: 10 首
# Maya Angelou: 10 首
# Ishmael Reed: 10 首
# Afaa Michael Weaver: 10 首
# Tomas Tranströmer: 10 首
# Stuart Dybek: 10 首
# David Trinidad: 10 首
# Mark Levine: 10 首
# Lucia Perillo: 10 首
# Sandra Simonds: 10 首
# Cathy Song: 10 首
# Javier Zamora: 10 首
# Monica Youn: 10 首
# Mark Strand: 10 首
# Maxine Kumin: 10 首
# Douglas Kearney: 10 首
# Luke Kennard: 10 首
# John Clare: 10 首
# Jonathan Swift: 10 首
# Adelaide Crapsey: 10 首
# Benjamin Franklin: 10 首
# David Bottoms: 10 首
# George Starbuck: 10 首
# Andrew Hudgins: 10 首
# Thomas McGrath: 10 首
# Basil Bunting: 10 首
# Rodney Jones: 10 首
# Countess of Winchilsea Anne Finch: 10 首
# Miroslav Holub: 10 首
# Charlotte Anna Perkins Gilman: 10 首
# Mahmoud Darwish: 10 首
# Rachel Wetzsteon: 10 首
# Debora Greger: 9 首
# Robert Wrigley: 9 首
# Adrian Matejka: 9 首
# Gerard Malanga: 9 首
# William Trowbridge: 9 首
# Anthony Madrid: 9 首
# Teresa Mei Chuc: 9 首
# Mark Rudman: 9 首
# Kazim Ali: 9 首
# Audre Lorde: 9 首
# Craig Santos Perez: 9 首
# Khaled Mattawa: 9 首
# Charles Olson: 9 首
# Joel Brouwer: 9 首
# Lisel Mueller: 9 首
# Nathalie Handal: 9 首
# Stephen Spender: 9 首
# Marilyn Chin: 9 首
# W. S. Graham: 9 首
# Mary Sidney Herbert Countess of Pembroke: 9 首
# Rachel Richardson: 9 首
# Chard DeNiord: 9 首
# John Brehm: 9 首
# Eamon Grennan: 9 首
# Kenneth Patchen: 9 首
# Cynthia Huntington: 9 首
# Bruce Lansky: 9 首
# Chana Bloch: 9 首
# Rebecca Hazelton: 9 首
# John Yau: 9 首
# Mary Szybist: 9 首
# Lorna Dee Cervantes: 9 首
# Nathaniel Mackey: 9 首
# Claude McKay: 9 首
# Jill McDonough: 9 首
# Paul Muldoon: 9 首
# Frances Ellen Watkins Harper: 9 首
# Nate Marshall: 9 首
# Cate Marvin: 9 首
# Francisco X. Alarcón: 9 首
# Margaret Fishback: 9 首
# Jim Harrison: 9 首
# Jean Valentine: 9 首
# Lynn Emanuel: 9 首
# Peter Cole: 9 首
# Emily Berry: 9 首
# Michael Hofmann: 9 首
# Kaveh Akbar: 9 首
# Natalie Shapero: 9 首
# Shane McCrae: 9 首
# Eduardo C. Corral: 9 首
# Laura Kasischke: 9 首
# Amy Beeder: 9 首
# William Logan: 9 首
# David Harsent: 9 首
# Geoffrey Brock: 9 首
# C. K. Williams: 9 首
# Linda Kunhardt: 9 首
# Richard Brautigan: 9 首
# Tomaž Šalamun: 9 首
# Rachel Hadas: 9 首
# Diane Wakoski: 9 首
# Arthur Sze: 9 首
# Ai: 9 首
# Robert Louis Stevenson: 9 首
# Thomas Carew: 9 首
# Stephen Crane: 9 首
# Lady Mary Wortley Montagu: 9 首
# Marjorie Pickthall: 9 首
# Thomas Traherne: 9 首
# Emma Lazarus: 9 首
# Robert Bridges: 9 首
# Hugh MacDiarmid: 9 首
# Robert Bly: 9 首
# Bruce Smith: 9 首
# Russell Edson: 9 首
# Marin Sorescu: 9 首
# Cesare Pavese: 9 首
# Osip Mandelstam: 8 首
# Francisco Aragón: 8 首
# Matthew Zapruder: 8 首
# Margaret Hasse: 8 首
# Rodney Koeneke: 8 首
# Rebecca Morgan Frank: 8 首
# Patricia Smith: 8 首
# Thomas Love Peacock: 8 首
# Alan Seeger: 8 首
# Charles Hamilton Sorley: 8 首
# John Frederick Nims: 8 首
# Allen Ginsberg: 8 首
# Yehuda Amichai: 8 首
# Edward Lear: 8 首
# Joshua Clover: 8 首
# Kenneth Rexroth: 8 首
# Rafael Campo: 8 首
# Roberto Tejada: 8 首
# Catherine Wagner: 8 首
# Landis Everson: 8 首
# Mark Jarman: 8 首
# Dick Allen: 8 首
# Peter Gizzi: 8 首
# John Spaulding: 8 首
# Minnie Bruce Pratt: 8 首
# George Moses Horton: 8 首
# Debra Nystrom: 8 首
# Georgia Douglas Johnson: 8 首
# Lucie Brock-Broido: 8 首
# Lucy Ives: 8 首
# Joyelle McSweeney: 8 首
# Raza Ali Hasan: 8 首
# G. K. Chesterton: 8 首
# Sudeep Sen: 8 首
# Donald Justice: 8 首
# Sydney Lea: 8 首
# Walter de La Mare: 8 首
# Amiri Baraka: 8 首
# Joyce Carol Oates: 8 首
# Major Jackson: 8 首
# Amit Majmudar: 8 首
# Dara Wier: 8 首
# Carol Muske-Dukes: 8 首
# Dana Levin: 8 首
# Hayan Charara: 8 首
# sam sax: 8 首
# Karen An-hwei Lee: 8 首
# Sylvia Legris: 8 首
# Katharine Coles: 8 首
# George Szirtes: 8 首
# Dave Smith: 8 首
# Joanie Mackowski: 8 首
# Weldon Kees: 8 首
# Craig Arnold: 8 首
# Tom Pickard: 8 首
# Sina Queyras: 8 首
# Bruce Weigl: 8 首
# Ellen Bryant Voigt: 8 首
# Louise Erdrich: 8 首
# Edgar Bowers: 8 首
# Agha Shahid Ali: 8 首
# David Ignatow: 8 首
# Babette Deutsch: 8 首
# Daryl Hine: 8 首
# William Cowper: 8 首
# Oliver Wendell Holmes Sr.: 8 首
# Charlotte Smith: 8 首
# Sir John Suckling: 8 首
# John Wilmot Earl of Rochester: 8 首
# Franklin Pierce Adams: 8 首
# John Reibetanz: 8 首
# Sophie Jewett: 8 首
# Thomas Merton: 8 首
# Jonathan Galassi: 8 首
# Kenneth Slessor: 8 首
# David Wojahn: 8 首
# John Logan: 8 首
# Charlie Smith: 8 首
# Peter Pereira: 8 首
# Roberta Hill: 8 首
# Lynda Hull: 8 首
# Jack Spicer: 8 首
# Alice Moore Dunbar-Nelson: 8 首
# Connie Wanek: 7 首
# Sueyeun Juliette Lee: 7 首
# Sandra Lim: 7 首
# Bei Dao: 7 首
# Peter Everwine: 7 首
# Kathryn Nuernberger: 7 首
# Karenne Wood: 7 首
# Ada Limón: 7 首
# Emily Jungmin Yoon: 7 首
# Richard Blanco: 7 首
# Simon Armitage: 7 首
# Geoffrey Chaucer: 7 首
# Miller Williams: 7 首
# Thylias Moss: 7 首
# Rosmarie Waldrop: 7 首
# Daniel Borzutzky: 7 首
# John Unterecker: 7 首
# Tom Raworth: 7 首
# James Longenbach: 7 首
# Rosanna Warren: 7 首
# Clark Coolidge: 7 首
# Ciaran Carson: 7 首
# Linda Hogan: 7 首
# Victor Hernández Cruz: 7 首
# Zachary Schomburg: 7 首
# Angela Jackson: 7 首
# Jake Adam York: 7 首
# Carmen Giménez Smith: 7 首
# Cynthia Cruz: 7 首
# Juan Delgado: 7 首
# Tarfia Faizullah: 7 首
# Kofi Awoonor: 7 首
# Allen Grossman: 7 首
# Claudia Rankine: 7 首
# Frank Bidart: 7 首
# Dorothy Parker: 7 首
# Terese Svoboda: 7 首
# James McMichael: 7 首
# Frederick Seidel: 7 首
# Molly Peacock: 7 首
# Jayne Cortez: 7 首
# Rebecca Seiferle: 7 首
# Mark Waldron: 7 首
# Alison C. Rollins: 7 首
# Ishion Hutchinson: 7 首
# Hieu Minh Nguyen: 7 首
# Annie Finch: 7 首
# Adam Zagajewski: 7 首
# Kabir: 7 首
# Paul Hoover: 7 首
# Averill Curdy: 7 首
# Michael Collier: 7 首
# Joshua Mehigan: 7 首
# Rickey Laurentiis: 7 首
# Michael Robbins: 7 首
# Dan Taulapapa McMullin: 7 首
# Max Ritvo: 7 首
# Alfred Corn: 7 首
# Grace Schulman: 7 首
# Bill Knott: 7 首
# Elizabeth Spires: 7 首
# Queen Elizabeth I: 7 首
# Henry VIII, King of England: 7 首
# Julia Ward Howe: 7 首
# James Whitcomb Riley: 7 首
# Philip Appleman: 7 首
# Marilyn Hacker: 7 首
# Kenn Nesbitt: 7 首
# Theodore Weiss: 7 首
# John Haines: 7 首
# G. E. Murray: 7 首
# Mary Barnard: 7 首
# Zbigniew Herbert: 7 首
# Michael Anania: 7 首
# Richard Emil Braun: 7 首
# Ronald Johnson: 7 首
# Frederick Goddard Tuckerman: 7 首
# John Peck: 7 首
# Juan Ramón Jiménez: 7 首
# Henry David Thoreau: 7 首
# Kenneth Fearing: 7 首
# Henry Dumas: 7 首
# Lady Mary Wroth: 7 首
# kari edwards: 7 首
# Donald (Grady) Davidson: 7 首
# Eric Ekstrand: 7 首
# Hester Knibbe: 7 首
# Dorothea Grossman: 7 首
# Barbara Ras: 6 首
# Sun Yung Shin: 6 首
# Andrew Motion: 6 首
# Joshua Edwards: 6 首
# Darren Sardelli: 6 首
# Bruce Guernsey: 6 首
# Luljeta Lleshanaku: 6 首
# Kiki Petrosino: 6 首
# Karen Volkman: 6 首
# dg nanouk okpik: 6 首
# Robert Morgan: 6 首
# Jameson Fitzpatrick: 6 首
# Richard Jones: 6 首
# Mónica de la Torre: 6 首
# Wisława Szymborska: 6 首
# Pimone Triplett: 6 首
# John Skelton: 6 首
# Robert Southey: 6 首
# Patricia Goedicke: 6 首
# Carter Revard: 6 首
# Timothy Donnelly: 6 首
# Barbara Jane Reyes: 6 首
# Jonathan Williams: 6 首
# Eleanor Ross Taylor: 6 首
# Jennifer Moxley: 6 首
# Joanne Kyger: 6 首
# Diane di Prima: 6 首
# Mark Doty: 6 首
# Rebecca Lindenberg: 6 首
# Allison Adelle Hedge Coke: 6 首
# Robert Polito: 6 首
# Hannah Gamble: 6 首
# Lisa Robertson: 6 首
# Allan Peterson: 6 首
# George Bilgere: 6 首
# Natalie Diaz: 6 首
# Philip Nikolayev: 6 首
# Tyrone Williams: 6 首
# Sherod Santos: 6 首
# Cleopatra Mathis: 6 首
# Michael Schmidt: 6 首
# Joshua Beckman: 6 首
# Oliver de la Paz: 6 首
# Jennifer Michael Hecht: 6 首
# Edward Hirsch: 6 首
# Nick Carbó: 6 首
# Rigoberto González: 6 首
# Jamaal May: 6 首
# Thomas Sayers Ellis: 6 首
# Deborah Landau: 6 首
# Edward Taylor: 6 首
# Jennifer Chang: 6 首
# Katrina Roberts: 6 首
# Juliana Spahr: 6 首
# Norma Cole: 6 首
# Timothy Yu: 6 首
# Tess Taylor: 6 首
# Carrie Fountain: 6 首
# Rebecca Wolff: 6 首
# Suzanne Buffam: 6 首
# Cyrus Cassells: 6 首
# Phillip B. Williams: 6 首
# Ocean Vuong: 6 首
# Patricia Lockwood: 6 首
# Natalie Scenters-Zapico: 6 首
# Fatimah Asghar: 6 首
# Cortney Lamar Charleston: 6 首
# John Lee Clark: 6 首
# Jack Underwood: 6 首
# Rick Barot: 6 首
# Adrienne Su: 6 首
# Bianca Stone: 6 首
# John Kinsella: 6 首
# Jill Alexander Essbaum: 6 首
# Fiona Sampson: 6 首
# Marina Tsvetaeva: 6 首
# Sara Miller: 6 首
# Matthew Nienow: 6 首
# David Orr: 6 首
# Christopher Middleton: 6 首
# Samiya Bashir: 6 首
# Robert Hayden: 6 首
# Hart Crane: 6 首
# Irving Feldman: 6 首
# Mary Jo Salter: 6 首
# Anna Lætitia Barbauld: 6 首
# Ambrose Bierce: 6 首
# Ernest M. Hemingway: 6 首
# Thomas Hood: 6 首
# Leigh Hunt: 6 首
# Richard Lovelace: 6 首
# Edmund Waller: 6 首
# George Santayana: 6 首
# Elinor Wylie: 6 首
# Gregory Corso: 6 首
# James Weldon Johnson: 6 首
# B. H. Fairchild: 6 首
# Christopher Smart: 6 首
# John Engels: 6 首
# Denis Johnson: 6 首
# Dannie Abse: 6 首
# Allen Tate: 6 首
# C. P. Cavafy: 6 首
# Kobayashi Issa: 6 首
# Robin Becker: 6 首
# Thomas James: 6 首
# Mary Mapes Dodge: 6 首
# Emily Wilson: 6 首
# Jack Collom: 6 首
# Etel Adnan: 6 首
# Jason Shinder: 6 首
# Kevin McFadden: 6 首
# Inger Christensen: 6 首
# Simone White: 5 首
# Judith Harris: 5 首
# Indran Amirthanayagam: 5 首
# James Masao Mitsui: 5 首
# Sarah Gambito: 5 首
# Eileen R. Tabios: 5 首
# T'ai Freedom Ford: 5 首
# Phillis Wheatley: 5 首
# Jill Bialosky: 5 首
# Pattiann Rogers: 5 首
# Marjorie Saiser: 5 首
# Randall Horton: 5 首
# Matthew Dickman: 5 首
# Maggie Smith: 5 首
# Tim Seibles: 5 首
# Jack Agüeros: 5 首
# Linda Rodriguez: 5 首
# Eduardo Chirinos: 5 首
# Donna Masini: 5 首
# David Hernandez: 5 首
# Deena Metzger: 5 首
# Jenny Xie: 5 首
# Robert Hedin: 5 首
# Ghassan Zaqtan: 5 首
# Diana Khoi Nguyen: 5 首
# Dan Gerber: 5 首
# Solmaz Sharif: 5 首
# Peggy Shumaker: 5 首
# John Masefield: 5 首
# Mark Irwin: 5 首
# Letitia Elizabeth Landon: 5 首
# Henry Howard, Earl of Surrey: 5 首
# Isabella Whitney: 5 首
# Sandra M. Gilbert: 5 首
# Grace Paley: 5 首
# Gregory Orr: 5 首
# Charles Ghigna: 5 首
# Linh Dinh: 5 首
# Timothy Liu: 5 首
# Douglas Florian: 5 首
# Jane Yolen: 5 首
# Joyce Sidman: 5 首
# Tsering Wangmo Dhompa: 5 首
# Thomas P. Lynch: 5 首
# Donald Davie: 5 首
# Meghan O'Rourke: 5 首
# Robert Fernandez: 5 首
# Ish Klein: 5 首
# David Dominguez: 5 首
# Paul Verlaine: 5 首
# L. E. Sissman: 5 首
# Luke Davies: 5 首
# Emily Warn: 5 首
# Théophile Gautier: 5 首
# Darcie Dennigan: 5 首
# Cole Swensen: 5 首
# Amy King: 5 首
# Paul Blackburn: 5 首
# Ariana Reines: 5 首
# Duchess of Newcastle Margaret Cavendish: 5 首
# Elizabeth Drew Barstow Stoddard: 5 首
# Henrietta Cordelia Ray: 5 首
# Sarah Morgan Bryan Piatt: 5 首
# Roy Fisher: 5 首
# Sappho: 5 首
# Dawn Lundy Martin: 5 首
# George Gascoigne: 5 首
# Philip Lamantia: 5 首
# Ko Un: 5 首
# John Barr: 5 首
# Barbara Crooker: 5 首
# Robert Winner: 5 首
# Tino Villanueva: 5 首
# J. Michael Martinez: 5 首
# Adrian Castro: 5 首
# Maurice Kilwein Guevara: 5 首
# Graham Foust: 5 首
# Jody Gladding: 5 首
# Sandy Florian: 5 首
# Laetitia Pilkington: 5 首
# Lee Herrick: 5 首
# Edith Wharton: 5 首
# Ravi Shankar: 5 首
# Michael Chitwood: 5 首
# David Roderick: 5 首
# Prageeta Sharma: 5 首
# Deborah Paredez: 5 首
# Katia Kapovich: 5 首
# Joe Brainard: 5 首
# Katie Ford: 5 首
# Jacqueline Woodson: 5 首
# Paul Carroll: 5 首
# Victoria Chang: 5 首
# Patricia Spears Jones: 5 首
# James Baldwin: 5 首
# Michael Dickman: 5 首
# Karen Solie: 5 首
# Frank Ormsby: 5 首
# Elizabeth Arnold: 5 首
# John Godfrey: 5 首
# Elizabeth Willis: 5 首
# Tyehimba Jess: 5 首
# Richard Michelson: 5 首
# John Tipton: 5 首
# Louis MacNeice: 5 首
# Sjohnna McCray: 5 首
# Lenelle Moïse: 5 首
# Susan Firer: 5 首
# Quraysh Ali Lansana: 5 首
# Haki R. Madhubuti: 5 首
# Elise Paschen: 5 首
# Geraldine Clarkson: 5 首
# Valzhyna Mort: 5 首
# Amy Key: 5 首
# Marion McCready: 5 首
# Sheryl Luna: 5 首
# Alice Lyons: 5 首
# Dora Malech: 5 首
# Nomi Stone: 5 首
# Charles North: 5 首
# Sam Riviere: 5 首
# Richard Kenney: 5 首
# Desirée Alvarez: 5 首
# Lisa Russ Spaar: 5 首
# Daisy Fried: 5 首
# Sophie Cabot Black: 5 首
# Anthony Hecht: 5 首
# Spencer Reece: 5 首
# Heidy Steidlmayer: 5 首
# Robert VanderMolen: 5 首
# Jason Guriel: 5 首
# Campbell McGrath: 5 首
# Sandra Beasley: 5 首
# Tomás Q. Morín: 5 首
# Rodrigo Toscano: 5 首
# Les Murray: 5 首
# Kathryn Maris: 5 首
# Guillaume Apollinaire: 5 首
# John Beer: 5 首
# Blas Falconer: 5 首
# Conor O'Callaghan: 5 首
# David Wagoner: 5 首
# Richard Eberhart: 5 首
# Phoebe Cary: 5 首
# Stephen C. Foster: 5 首
# Thomas Gray: 5 首
# Charles Lamb: 5 首
# Susanna Moodie: 5 首
# James Clerk Maxwell: 5 首
# Lynn Crosbie: 5 首
# Sir Arthur Conan Doyle: 5 首
# Phil Bolsta: 5 首
# Timothy Steele: 5 首
# Lisa Olstein: 5 首
# Robert Lowell: 5 首
# Anna Swir: 5 首
# Robert Fitzgerald: 5 首
# Pablo Neruda: 5 首
# Michael Field: 5 首
# Hilda Raz: 5 首
# Susan Griffin: 5 首
# Clarence Major: 5 首
# Philip Whalen: 5 首
# John Gay: 5 首
# Joanna Baillie: 5 首
# Isaac Watts: 5 首
# Norman Williams: 5 首
# Alice Cary: 5 首
# Ella Higginson: 5 首
# Brian Culhane: 5 首
# William Barnes: 5 首
# Calvin Thomas Jr.: 5 首
# Thulani Davis: 5 首
# Margaret Walker: 5 首
# Chris Abani: 5 首
# Amaud Jamaul Johnson: 5 首
# Sabrina Orah Mark: 5 首
# Cheryl Savageau: 5 首
# Fred Marchant: 5 首
# Pierre Martory: 5 首
# Ho Xuan Huong: 5 首
# Seth Abramson: 5 首
# John Bunyan: 5 首
# Michael Gessner: 4 首
# Margarita Engle: 4 首
# Rick Noguchi: 4 首
# Juliet Kono: 4 首
# Shin Yu Pai: 4 首
# Cathy Linh Che: 4 首
# Eric Gamalinda: 4 首
# Dan Vera: 4 首
# Douglas Manuel: 4 首
# Diane Gilliam Fisher: 4 首
# Cynthia Zarin: 4 首
# Koon Woon: 4 首
# Mari L'Esperance: 4 首
# Veronica Forrest-Thomson: 4 首
# Hoa Nguyen: 4 首
# Julien Poirier: 4 首
# Leslie Harrison: 4 首
# Anna Rabinowitz: 4 首
# Vi Khi Nao: 4 首
# Johannes Göransson: 4 首
# Tami Haaland: 4 首
# Jonterri Gadson: 4 首
# Terri Kirby Erickson: 4 首
# Jeffrey Harrison: 4 首
# Aleida Rodríguez: 4 首
# Angela C. Trudell Vasquez: 4 首
# Levi Romero: 4 首
# Joseph Di Prisco: 4 首
# Ruben Quesada: 4 首
# M.L. Smoker: 4 首
# Janice Gould: 4 首
# Ron Rash: 4 首
# Gordon Henry Jr.: 4 首
# Janet McAdams: 4 首
# Sy Hoahwah: 4 首
# Peter Oresick: 4 首
# Carol V. Davis: 4 首
# David Mason: 4 首
# Pauli Murray: 4 首
# Jim Daniels: 4 首
# Justin Phillip Reed: 4 首
# Gerrit Lansing: 4 首
# George Sterling: 4 首
# Faith Shearin: 4 首
# Ron Koertge: 4 首
# Sally Wen Mao: 4 首
# John Trudell: 4 首
# Lizette Woodworth Reese: 4 首
# Esther Belin: 4 首
# Adrienne Rich: 4 首
# Omar Pérez: 4 首
# Tim Nolan: 4 首
# Stéphane Mallarmé: 4 首
# Bruce Covey: 4 首
# John Hennessy: 4 首
# Roxane Beth Johnson: 4 首
# Aaron Shurin: 4 首
# John Taggart: 4 首
# Michael McFee: 4 首
# Brenda Cárdenas: 4 首
# Lisa Jarnot: 4 首
# Roy Scheele: 4 首
# Stanley Kunitz: 4 首
# Arthur Symons: 4 首
# Ken Mikolowski: 4 首
# Micah Ballard: 4 首
# Vicki Hearne: 4 首
# Connie Voisine: 4 首
# Don Bogen: 4 首
# Richard O. Moore: 4 首
# Fay Zwicky: 4 首
# Denise Low: 4 首
# Dilruba Ahmed: 4 首
# Andrew Allport: 4 首
# Sasha Steensen: 4 首
# Brandon Brown: 4 首
# Garrett Caples: 4 首
# Dana Ward: 4 首
# Kathleen Rooney: 4 首
# Mark O'Brien: 4 首
# Kate Buckley: 4 首
# Adrian C. Louis: 4 首
# Wendell Berry: 4 首
# Camille Guthrie: 4 首
# Curzio Malaparte: 4 首
# Erin Belieu: 4 首
# Raymond McDaniel: 4 首
# Baron Brooke Fulke Greville: 4 首
# Anna Moschovakis: 4 首
# Li Po: 4 首
# David Lau: 4 首
# Jesús Papoleto Meléndez: 4 首
# Hilda Morley: 4 首
# Jerome Rothenberg: 4 首
# Robert Nichols: 4 首
# James Schuyler: 4 首
# Derek Walcott: 4 首
# Alexandria Peary: 4 首
# Tina Chang: 4 首
# Suji Kwock Kim: 4 首
# Martha Collins: 4 首
# Rosemary Tonks: 4 首
# Lloyd Schwartz: 4 首
# Pat Mora: 4 首
# Jon Pineda: 4 首
# Vandana Khanna: 4 首
# Marjorie Agosín: 4 首
# Yolanda Wisher: 4 首
# David Tomas Martinez: 4 首
# Michael Miller: 4 首
# Erika Meitner: 4 首
# Sandra M. Castillo: 4 首
# Tato Laviera: 4 首
# Gabrielle Calvocoressi: 4 首
# Pedro Pietri: 4 首
# Valerie Wetlaufer: 4 首
# Monica McClure: 4 首
# Robin Coste Lewis: 4 首
# Lia Purpura: 4 首
# Jane Mead: 4 首
# Camille Rankine: 4 首
# Robyn Schiff: 4 首
# Andrew Shields: 4 首
# Don Mee Choi: 4 首
# Idra Novey: 4 首
# Andrew Joron: 4 首
# Robin Morgan: 4 首
# Hannah Brooks-Motl: 4 首
# Jana Prikryl: 4 首
# Ted Greenwald: 4 首
# Lynn Pedersen: 4 首
# Anne Spencer: 4 首
# Emmy Pérez: 4 首
# Daniel Tobin: 4 首
# Donald Britton: 4 首
# Vahni Capildeo: 4 首
# Dale Going: 4 首
# Michael Hartnett: 4 首
# Melissa Broder: 4 首
# CM Burroughs: 4 首
# Mai Der Vang: 4 首
# Roy G. Guzmán: 4 首
# Bill Manhire: 4 首
# Anselm Berrigan: 4 首
# Joel Lipman: 4 首
# Safia Elhillo: 4 首
# Alex Dimitrov: 4 首
# Elena Karina Byrne: 4 首
# Heather Christle: 4 首
# Martha Zweig: 4 首
# Michael Farrell: 4 首
# Pascale Petit: 4 首
# Tess Gallagher: 4 首
# Miriam Bird Greenberg: 4 首
# Angel Nafis: 4 首
# Maria Hummel: 4 首
# John Gallaher: 4 首
# Catie Rosemurgy: 4 首
# Michele Wolf: 4 首
# Stephen Yenser: 4 首
# Amrita Pritam: 4 首
# Robin Robertson: 4 首
# Melanie Braverman: 4 首
# Marcus Wicker: 4 首
# Greg Glazner: 4 首
# Kimiko Hahn: 4 首
# Kathleen Jamie: 4 首
# Michael Lista: 4 首
# Julian Stannard: 4 首
# Dan Brown: 4 首
# Derek Sheffield: 4 首
# Peter Spagnuolo: 4 首
# Wilmer Mills: 4 首
# Sherman Alexie: 4 首
# Pierre Reverdy: 4 首
# Leah Umansky: 4 首
# Adam Fitzgerald: 4 首
# Nance Van Winckel: 4 首
# Maria Melendez Kelson: 4 首
# Jacob Saenz: 4 首
# April Bernard: 4 首
# Abraham Sutzkever: 4 首
# Jamila Woods: 4 首
# Kathryn Starbuck: 4 首
# Stanley Plumly: 4 首
# Honorée Fanonne Jeffers: 4 首
# Jan Beatty: 4 首
# David Shapiro: 4 首
# Francis Ponge: 4 首
# Honor Moore: 4 首
# Susan Howe: 4 首
# Carl Dennis: 4 首
# Lewis Carroll: 4 首
# William Collins: 4 首
# Thomas Moore: 4 首
# Katherine Philips: 4 首
# Mary Robinson: 4 首
# Sir Walter Scott: 4 首
# Simon J. Ortiz: 4 首
# Amy Uyematsu: 4 首
# Constance Urdang: 4 首
# Sarah Orne Jewett: 4 首
# Garrett Hongo: 4 首
# Ann Lauterbach: 4 首
# Susan Mitchell: 4 首
# Richard Howard: 4 首
# Seamus Heaney: 4 首
# Primus St. John: 4 首
# Bin Ramke: 4 首
# Odysseus Elytis: 4 首
# Edmond Jabès: 4 首
# Neal Bowers: 4 首
# Marianne Moore: 4 首
# Ben Lerner: 4 首
# Elizabeth Hands: 4 首
# Anna Seward: 4 首
# Jane Taylor: 4 首
# Mary Lamb: 4 首
# Lydia Huntley Sigourney: 4 首
# Jupiter Hammon: 4 首
# Jones Very: 4 首
# Colleen J. McElroy: 4 首
# David Lee: 4 首
# Wanda Coleman: 4 首
# Lorenzo Thomas: 4 首
# Léopold Sédar Senghor: 4 首
# Elizabeth Woody: 4 首
# Wendy Rose: 4 首
# Ofelia Zepeda: 4 首
# Jennifer Scappettone: 4 首
# Myung Mi Kim: 4 首
# Ana Božičević: 4 首
# Mei-mei Berssenbrugge: 4 首
# Srikanth Reddy: 4 首
# Edwin Torres: 4 首
# Raúl Zurita: 4 首
# George Albon: 4 首
# Deborah A. Miranda: 4 首
# Gerald Vizenor: 4 首
# Richard Aldington: 4 首
# Edith Sitwell: 4 首
# Leslie Adrienne Miller: 4 首
# Nick Lantz: 4 首
# Elfriede Jelinek: 4 首
# Peter Campion: 4 首
# Harry Clifton: 4 首
# Barbara Howes: 4 首
# Grace Cavalieri: 3 首
# Tao Lin: 3 首
# Christina Pugh: 3 首
# Ha Jin: 3 首
# April Ossmann: 3 首
# Jaswinder Bolina: 3 首
# Cynthia Hogue: 3 首
# Fleda Brown: 3 首
# James Crews: 3 首
# Daniel Nadler: 3 首
# Aziza Barnes: 3 首
# W. Todd Kaneko: 3 首
# Divya Victor: 3 首
# Lesley Harrison: 3 首
# TC Tolbert: 3 首
# Greg Delanty: 3 首
# Elizabeth A.I. Powell: 3 首
# Joseph Massey: 3 首
# Gillian Conoley: 3 首
# Jack Kerouac: 3 首
# Chinua Achebe: 3 首
# Jennifer Wong: 3 首
# Eric Gansworth: 3 首
# Luis J. Rodríguez: 3 首
# Luci Tapahonso: 3 首
# Adam Clay: 3 首
# Olivia Maciel: 3 首
# Jehanne Dubrow: 3 首
# James K. Zimmerman: 3 首
# Marilyn Singer: 3 首
# Noah Warren: 3 首
# Tacey M. Atsitty: 3 首
# Raina J. León: 3 首
# William Archila: 3 首
# Olena Kalytiak Davis: 3 首
# Olav H. Hauge: 3 首
# Jenny George: 3 首
# Melissa Stein: 3 首
# David Budbill: 3 首
# LeAnne Howe: 3 首
# Maryann Corbett: 3 首
# Mark Tardi: 3 首
# Donika Kelly: 3 首
# Ursula K. Le Guin: 3 首
# Aase Berg: 3 首
# Bill Zavatsky: 3 首
# Rusty Morrison: 3 首
# Caitlin Doyle: 3 首
# Thomas Reiter: 3 首
# Lois Red Elk: 3 首
# Elise Hempel: 3 首
# Joseph O. Legaspi: 3 首
# Carl Marcum: 3 首
# Gabriel Gomez: 3 首
# Paul Martínez Pompa: 3 首
# Lewis Warsh: 3 首
# Taha Muhammad Ali: 3 首
# Sara Holbrook: 3 首
# David L. Harrison: 3 首
# Charles Baudelaire: 3 首
# Kathleen Graber: 3 首
# Mona Van Duyn: 3 首
# Marilyn L. Taylor: 3 首
# Paul Foster Johnson: 3 首
# Kate Greenstreet: 3 首
# Michael McClure: 3 首
# Reginald Shepherd: 3 首
# Alison Hawthorne Deming: 3 首
# Marie Howe: 3 首
# Gregory Pardlo: 3 首
# April Lindner: 3 首
# Frank Marshall Davis: 3 首
# Leo Dangel: 3 首
# Andrei Codrescu: 3 首
# Don Thompson: 3 首
# Colette Labouff Atkinson: 3 首
# Liam Rector: 3 首
# Peg Boyers: 3 首
# David Gewanter: 3 首
# Jan Owen: 3 首
# Caroline Caddy: 3 首
# Chris Wallace-Crabbe: 3 首
# Geoff Page: 3 首
# Michael Sharkey: 3 首
# Richard Tagett: 3 首
# Susan Hampton: 3 首
# joanne burns: 3 首
# Shel Silverstein: 3 首
# Anya Silver: 3 首
# Carrie Shipers: 3 首
# Mark Vinz: 3 首
# Jennifer Grotz: 3 首
# Ron Silliman: 3 首
# Judith Slater: 3 首
# E. Tracy Grinnell: 3 首
# H. L. Hix: 3 首
# Karyna McGlynn: 3 首
# Samuel Greenberg: 3 首
# George Henry Boker: 3 首
# Barton Sutter: 3 首
# Susan Wheeler: 3 首
# Henri Cole: 3 首
# Steve Kistulentz: 3 首
# Joel Craig: 3 首
# Nick Twemlow: 3 首
# X J Kennedy: 3 首
# James Doyle: 3 首
# Joseph Millar: 3 首
# Christina Davis: 3 首
# LaTasha N. Nevada Diggs: 3 首
# Gina Franco: 3 首
# Jonathan Greene: 3 首
# Amy Fleury: 3 首
# Andrea Hollander: 3 首
# David Allan Evans: 3 首
# Brian Russell: 3 首
# Tishani Doshi: 3 首
# Mary Margaret Alvarado: 3 首
# Valerie Mejer Caso: 3 首
# Carmen Tafolla: 3 首
# Ed Bok Lee: 3 首
# Andrew Zawacki: 3 首
# Priscilla Lee: 3 首
# Xochiquetzal Candelaria: 3 首
# Sharon Chmielarz: 3 首
# Brian Komei Dempster: 3 首
# Clifton Gachagua: 3 首
# Elise Partridge: 3 首
# Edmund Blunden: 3 首
# Laurence Binyon: 3 首
# Arthur Graeme West: 3 首
# Vera Mary Brittain: 3 首
# Margaret Postgate Cole: 3 首
# Elizabeth Bishop: 3 首
# May Wedderburn Cannan: 3 首
# Randall Jarrell: 3 首
# Edgell Rickword: 3 首
# Don Welch: 3 首
# Kurt Brown: 3 首
# Mong-Lan: 3 首
# Chitra Banerjee Divakaruni: 3 首
# Judith Ortiz Cofer: 3 首
# Silvia Curbelo: 3 首
# Emily Rosko: 3 首
# Brian Blanchfield: 3 首
# Joyce Peseroff: 3 首
# Morgan Parker: 3 首
# Patrick Phillips: 3 首
# Philip Jenks: 3 首
# Orlando White: 3 首
# Cecilia Vicuña: 3 首
# Elaine Kahn: 3 首
# Joanna Fuhrman: 3 首
# Freya Manfred: 3 首
# Tory Dent: 3 首
# Janet McNally: 3 首
# Marsha De La O: 3 首
# Eva Saulitis: 3 首
# Eileen Spinelli: 3 首
# Francine Sterle: 3 首
# James Lasdun: 3 首
# Roald Dahl: 3 首
# Joseph Gordon Macleod: 3 首
# Todd Colby: 3 首
# Sara Nicholson: 3 首
# Ben Estes: 3 首
# Alfred Starr Hamilton: 3 首
# Alan Feldman: 3 首
# Mark McMorris: 3 首
# Catherine Bowman: 3 首
# Richard Katrovas: 3 首
# Rachel Galvin: 3 首
# Kate Colby: 3 首
# Joy Katz: 3 首
# Fred D'Aguiar: 3 首
# Roger Reeves: 3 首
# Hannah Lowe: 3 首
# Franny Choi: 3 首
# Beth Bachmann: 3 首
# Drew Gardner: 3 首
# Robert Adamson: 3 首
# Jane Yeh: 3 首
# Kristen Tracy: 3 首
# Mark Laliberte: 3 首
# Rosebud Ben-Oni: 3 首
# Ari Banias: 3 首
# Camonghne Felix: 3 首
# Raymond Antrobus: 3 首
# Trevino L. Brings Plenty: 3 首
# Crisosto Apache: 3 首
# Robin Richardson: 3 首
# Catherine Barnett: 3 首
# Zack Strait: 3 首
# Claudine Toutoungi: 3 首
# Christine Gosnay: 3 首
# Nicky Beer: 3 首
# Amir Khadar: 3 首
# Brad Trumpfheller: 3 首
# Caroline Bird: 3 首
# Zeina Hashem Beck: 3 首
# Shira Dentz: 3 首
# Huang Fan: 3 首
# Brian Kim Stefans: 3 首
# Reginald Dwayne Betts: 3 首
# Miller Oberman: 3 首
# Richard Garcia: 3 首
# Philip Metres: 3 首
# T.J. Jarrett: 3 首
# Sarah Holland-Batt: 3 首
# Jessica Jopp: 3 首
# Sasha Dugdale: 3 首
# Malachi Black: 3 首
# Edith Södergran: 3 首
# Ray Amorosi: 3 首
# Olivia Clare: 3 首
# T. Zachary Cotler: 3 首
# Allison Seay: 3 首
# Janet Loxley Lewis: 3 首
# Patricia Kirkpatrick: 3 首
# Beverley Bie Brahic: 3 首
# Amy Clampitt: 3 首
# Steve Gehrke: 3 首
# Saskia Hamilton: 3 首
# Brian Swann: 3 首
# Rachel Jamison Webster: 3 首
# David Barber: 3 首
# Adam Kirsch: 3 首
# Anna Maria Hong: 3 首
# J. T. Barbarese: 3 首
# Phillis Levin: 3 首
# Sadiqa de Meijer: 3 首
# Maureen N. McLane: 3 首
# Liz Waldner: 3 首
# Tiffany Higgins: 3 首
# Hannah Sanghee Park: 3 首
# Emilia Phillips: 3 首
# Maxine Chernoff: 3 首
# Danniel Schoonebeek: 3 首
# Michael Earl Craig: 3 首
# Najwan Darwish: 3 首
# Amanda Calderon: 3 首
# Rowan Ricardo Phillips: 3 首
# Arthur Vogelsang: 3 首
# Rory Waterman: 3 首
# Dafydd ap Gwilym: 3 首
# Shuzo Takiguchi: 3 首
# Yves Bonnefoy: 3 首
# Knar Gavin: 3 首
# Michael Metivier: 3 首
# Erika L. Sánchez: 3 首
# Nico Vassilakis: 3 首
# Alan Gillis: 3 首
# Maceo J. Whitaker: 3 首
# Valerie Martínez: 3 首
# Daniela Danz: 3 首
# Federico García Lorca: 3 首
# Calvin Forbes: 3 首
# George Bowering: 3 首
# W. E. B. Du Bois: 3 首
# Richard Hugo: 3 首
# Conrad Aiken: 3 首
# Theodore Roethke: 3 首
# Charles Wesley: 3 首
# William Lisle Bowles: 3 首
# Thomas Carlyle: 3 首
# Lady Mary Chudleigh: 3 首
# Samuel Johnson: 3 首
# Ann Taylor: 3 首
# George Elliott Clarke: 3 首
# Leslie Monsour: 3 首
# Margaret Fuller: 3 首
# Rhina P. Espaillat: 3 首
# Katherine Mansfield: 3 首
# John Berryman: 3 首
# Alfred Noyes: 3 首
# P. K. Page: 3 首
# Walter McDonald: 3 首
# George Bradley: 3 首
# Horace: 3 首
# William H. Dickey: 3 首
# Sue Ellen Thompson: 3 首
# Lawrence Raab: 3 首
# Dionisio D. Martínez: 3 首
# Jean Nordhaus: 3 首
# Henry Carlile: 3 首
# William Drummond of Hawthornden: 3 首
# Helen Hunt Jackson: 3 首
# Christopher Marlowe: 3 首
# Rynn Williams: 3 首
# Patti Smith: 3 首
# Hafez: 3 首
# Susanna Blamire: 3 首
# Mary Elizabeth Coleridge: 3 首
# Edward Dorn: 3 首
# Charlotte Richardson: 3 首
# Dorothy Wordsworth: 3 首
# Hannah F. Gould: 3 首
# Frances Anne Kemble: 3 首
# Frances Jane Crosby Van Alstyne: 3 首
# Queen Lydia Kamakaeha Lili’uokalani: 3 首
# Mary Weston Fordham: 3 首
# Carolyn Wells: 3 首
# Adrian Blevins: 3 首
# Hartley Coleridge: 3 首
# Carolyn M. Rodgers: 3 首
# Kate Gale: 3 首
# Judy Grahn: 3 首
# Eloise Klein Healy: 3 首
# Terry Wolverton: 3 首
# Rachel Zucker: 3 首
# Anita Endrezze: 3 首
# Hershman John: 3 首
# Ralph Salisbury: 3 首
# Nora Marks Dauenhauer: 3 首
# Judith Goldman: 3 首
# Stacy Szymaszek: 3 首
# Jeffrey Jullich: 3 首
# Tod Marshall: 3 首
# Paul Killebrew: 3 首
# Nate Pritts: 3 首
# Israel Zangwill: 3 首
# Phillip Carroll Morgan: 3 首
# Kimberly Blaeser: 3 首
# James Thomas Stevens: 3 首
# Allison Titus: 3 首
# William Faulkner: 3 首
# Jonathan David: 3 首
# Dobby Gibson: 3 首
# Rainer Maria Rilke: 3 首
# Franco Fortini: 3 首
# William Johnson: 3 首
# János Pilinszky: 3 首
# Chris Dombrowski: 3 首
# Jill Osier: 3 首
# Joan Houlihan: 3 首
# Peter Munro: 3 首
# Allen Edwin Butt: 3 首
# Mark Wunderlich: 3 首
# Don Paterson: 3 首
# A. V. Christie: 3 首
# Gisela Kraft: 3 首
# Christopher Shannon: 3 首
# Brooklyn Copeland: 3 首
# Lilian Moore: 3 首
# George H. Dillon: 3 首
# Cathryn Essinger: 2 首
# Truong Tran: 2 首
# Eugene Gloria: 2 首
# Nikki Wallschlaeger: 2 首
# Shara McCallum: 2 首
# Joseph Hutchison: 2 首
# Nancy Willard: 2 首
# Pat Schneider: 2 首
# Mary O'Donnell: 2 首
# Emily Skillings: 2 首
# Naomi Replansky: 2 首
# Thomas R. Moore: 2 首
# James Hoch: 2 首
# Christopher Soto: 2 首
# Solomon Ibn Gabirol: 2 首
# Jen Hofer: 2 首
# Sean Thomas Dougherty: 2 首
# Chrystos: 2 首
# Alurista: 2 首
# Laura Da': 2 首
# Michael Klein: 2 首
# elena minor: 2 首
# Betty Adcock: 2 首
# Merrill Leffler: 2 首
# Saundra Rose Maley: 2 首
# Philip Raisor: 2 首
# Cathy Tagnak Rexford: 2 首
# Alejandra Pizarnik: 2 首
# Hanif Abdurraqib: 2 首
# Samuel Green: 2 首
# Katy Lederer: 2 首
# Susan Eisenberg: 2 首
# John L. Stanizzi: 2 首
# Pauletta Hansel: 2 首
# Jeanie Greensfelder: 2 首
# Layli Long Soldier: 2 首
# William Dunbar: 2 首
# John McCrae: 2 首
# James Thomson (Bysshe Vanolis): 2 首
# Julian Grenfell: 2 首
# Harriet Monroe: 2 首
# Sean Nevin: 2 首
# Rachel Loden: 2 首
# Susan M. Schultz: 2 首
# Avis Harley: 2 首
# Heidi Mordhorst: 2 首
# Ellery Akers: 2 首
# Nicole Brossard: 2 首
# Renee Gladman: 2 首
# Chip Livingston: 2 首
# Urayoán Noel: 2 首
# Kristine O'Connell George: 2 首
# Ashley Anna McHugh: 2 首
# P. Inman: 2 首
# John Wieners: 2 首
# Jane Miller: 2 首
# Jane Cooper: 2 首
# W.D. Ehrhart: 2 首
# J. T. Ledbetter: 2 首
# Greg Miller: 2 首
# Kris Hemensley: 2 首
# Mark Tredinnick: 2 首
# Judith Beveridge: 2 首
# Peter Boyle: 2 首
# Brook Emery: 2 首
# David Musgrave: 2 首
# Richard Newman: 2 首
# Richard Levine: 2 首
# Rabi'a: 2 首
# Brian Henry: 2 首
# Gaspara Stampa: 2 首
# Jacqueline Osherow: 2 首
# Dorothea Tanning: 2 首
# Janet Eigner: 2 首
# Brandon Shimoda: 2 首
# Linda Norton: 2 首
# Linda Parsons Marion: 2 首
# Rita Ann Higgins: 2 首
# Jo McDougall: 2 首
# Richard Owens: 2 首
# Lucy Larcom: 2 首
# Sarah C. Harwell: 2 首
# Bob Kaufman: 2 首
# Jan Heller Levi: 2 首
# Nikky Finney: 2 首
# Robert Gibb: 2 首
# Jeff Daniel Marion: 2 首
# Marsha Truman Cooper: 2 首
# Bruce Snider: 2 首
# Laura Mullen: 2 首
# Gabriel Spera: 2 首
# Sheryl St. Germain: 2 首
# James Shirley: 2 首
# Sharon Mesmer: 2 首
# Lynn Xu: 2 首
# Chelsea Rathburn: 2 首
# Robert Haight: 2 首
# John Philip Johnson: 2 首
# Rose Fyleman: 2 首
# Emanuel Xavier: 2 首
# Stephanie Young: 2 首
# Susan Kelly-DeWitt: 2 首
# Barbara Hamby: 2 首
# Suzanne Gardinier: 2 首
# Calvin Bedient: 2 首
# Esther Lee: 2 首
# David Mura: 2 首
# George Quasha: 2 首
# John Davies: 2 首
# Nathaniel Hawthorne: 2 首
# Katharine Tynan: 2 首
# Wilfrid Wilson Gibson: 2 首
# Thom Gunn: 2 首
# Jennifer Gray: 2 首
# Stuart Kestenbaum: 2 首
# Ilya Kutik: 2 首
# Jennifer Elise Foerster: 2 首
# Joshua Weiner: 2 首
# Luisa A. Igloria: 2 首
# Kwame Dawes: 2 首
# Ned Balbo: 2 首
# Jon Leon: 2 首
# Ed Ochester: 2 首
# Joseph Bruchac: 2 首
# John Hollander: 2 首
# Jennifer Maiden: 2 首
# Daniel Tiffany: 2 首
# Laura Moriarty: 2 首
# Monica Ferrell: 2 首
# Lawson Fusao Inada: 2 首
# Khadijah Queen: 2 首
# Patricia Traxler: 2 首
# Anne Boyer: 2 首
# Mary Hickman: 2 首
# Paolo Javier: 2 首
# Jack Gilbert: 2 首
# Fran Haraway: 2 首
# Rebecca Kai Dotlich: 2 首
# James Kimbrell: 2 首
# Stephanie Gray: 2 首
# Carole Boston Weatherford: 2 首
# Bob Perelman: 2 首
# May Sarton: 2 首
# Margaret Avison: 2 首
# April Halprin Wayland: 2 首
# Amy E. Sklansky: 2 首
# Warsan Shire: 2 首
# Sallie Wolf: 2 首
# Katherine Hauth: 2 首
# Jana Harris: 2 首
# Emily Pérez: 2 首
# Nuala Ní Dhomhnaill: 2 首
# Hai-Dang Phan: 2 首
# Sergey Gandlevsky: 2 首
# A.B. Jackson: 2 首
# Gillian Allnutt: 2 首
# Liz Berry: 2 首
# Mahogany L. Browne: 2 首
# Jeffrey Yang: 2 首
# Rajiv Mohabir: 2 首
# Elizabeth Metzger: 2 首
# Mario Meléndez: 2 首
# Chen Jun: 2 首
# Joel Dias-Porter: 2 首
# Duy Doan: 2 首
# Bruce Bond: 2 首
# Sumita Chakraborty: 2 首
# Durs Grünbein: 2 首
# Cynthia Arrieu-King: 2 首
# Jake Crist: 2 首
# Clare Jones: 2 首
# Ben Ladouceur: 2 首
# Ian Williams: 2 首
# Jennifer Givhan: 2 首
# Joshua Bennett: 2 首
# Paige Lewis: 2 首
# Robert Sullivan: 2 首
# Gregory O’Brien: 2 首
# Carla Panciera: 2 首
# Frances Leviston: 2 首
# Lani O'Hanlon: 2 首
# Kinga Tóth: 2 首
# Michael Wasson: 2 首
# Tanaya Winder: 2 首
# Keith S. Wilson: 2 首
# Mia Kang: 2 首
# Jayme Ringleb: 2 首
# Gregory Maguire: 2 首
# Jane Wong: 2 首
# Robin Gow: 2 首
# Toby Martinez de las Rivas: 2 首
# Krista Franklin: 2 首
# Mona Arshi: 2 首
# Paul Tran: 2 首
# John Shoptaw: 2 首
# Yi Sang: 2 首
# Ken Chen: 2 首
# Traci Brimhall: 2 首
# Penelope Shuttle: 2 首
# Mary Meriam: 2 首
# Gabrielle Bates: 2 首
# Thomas McCarthy: 2 首
# Bev Yockelson: 2 首
# Rocket Caleshu: 2 首
# Naomi Cohn: 2 首
# Stephen Sexton: 2 首
# Anthony Lawrence: 2 首
# Alyssa Moore: 2 首
# Ru Freeman: 2 首
# Momtaza Mehri: 2 首
# Paula Bohince: 2 首
# Natalie Eilbert: 2 首
# Libby Burton: 2 首
# Wayne Holloway-Smith: 2 首
# Neil Carpathios: 2 首
# Anna Akhmatova: 2 首
# Todd Swift: 2 首
# John M. Ridland: 2 首
# Clive James: 2 首
# Eugénio de Andrade: 2 首
# Reina María Rodríguez: 2 首
# Bertolt Brecht: 2 首
# Amanda Jernigan: 2 首
# Bryan D. Dietrich: 2 首
# Vijay Seshadri: 2 首
# David Biespiel: 2 首
# John Matthias: 2 首
# Kathy Nilsson: 2 首
# Tara Bray: 2 首
# John Repp: 2 首
# Dore Kiesselbach: 2 首
# Robin Ekiss: 2 首
# Elizabeth Seydel Morgan: 2 首
# Lisa Williams: 2 首
# Brad Leithauser: 2 首
# Shann Ray: 2 首
# Sara Peters: 2 首
# Daniel Halpern: 2 首
# Vanessa Place: 2 首
# Mary Moore Easter: 2 首
# Gwyneth Lewis: 2 首
# Robert Thomas: 2 首
# Philip Schultz: 2 首
# Mark Bibbins: 2 首
# Kathleen Ossip: 2 首
# Mark Ford: 2 首
# Troy Jollimore: 2 首
# K. Silem Mohammad: 2 首
# Sheila Black: 2 首
# Shailja Patel: 2 首
# Dolores Hayden: 2 首
# Ian Duhig: 2 首
# Joshua Corey: 2 首
# Caroline Bergvall: 2 首
# Dan Chelotti: 2 首
# Stephen Sturgeon: 2 首
# Lisa Ampleman: 2 首
# Susan Barba: 2 首
# Kathryn Simmonds: 2 首
# Ruby Robinson: 2 首
# Caleb Klaces: 2 首
# Tim Wells: 2 首
# Liu Xia: 2 首
# Peter Ciccariello: 2 首
# Chen Chen: 2 首
# Bridget Lowe: 2 首
# Rebecca Gayle Howell: 2 首
# derek beaulieu: 2 首
# Kirby Knowlton: 2 首
# Ailbhe Darcy: 2 首
# Ciaran Berry: 2 首
# Victoria Kennefick: 2 首
# Billy Ramsell: 2 首
# Ailbhe Ní Ghearbhuigh: 2 首
# Michelle O’Sullivan: 2 首
# Paul Perry: 2 首
# Susan Elizabeth Howe: 2 首
# Charles Harper Webb: 2 首
# Eisder Mosquera: 2 首
# Vona Groarke: 2 首
# Alan Ramón Clinton: 2 首
# Lisa Grove: 2 首
# Joanne Diaz: 2 首
# Jaap Blonk: 2 首
# Safiya Sinclair: 2 首
# Sarah Browning: 2 首
# Gretchen Marquette: 2 首
# Kristin Naca: 2 首
# Orlando Ricardo Menes: 2 首
# Laurie Ann Guerrero: 2 首
# Jaya Savige: 2 首
# Gig Ryan: 2 首
# Amanda Joy: 2 首
# Elizabeth Campbell: 2 首
# Ali Cobby Eckermann: 2 首
# Samuel Wagan Watson: 2 首
# John Hodgen: 2 首
# Howard Altmann: 2 首
# Pierluigi Cappello: 2 首
# Ernst Jandl: 2 首
# René Magritte: 2 首
# Donovan Kūhiō Colleps: 2 首
# Jacob Polley: 2 首
# Clark Moore: 2 首
# Isabel Rogers: 2 首
# Michael Symmons Roberts: 2 首
# S.J. Fowler: 2 首
# Lisa Gill: 2 首
# Clare Pollard: 2 首
# Lawrence Joseph: 2 首
# Isabel Galleymore: 2 首
# Johnny Damm: 2 首
# Lucy Wainger: 2 首
# Gergely Normal: 2 首
# giovanni singleton: 2 首
# Jessy Randall: 2 首
# Jacob Shores-Argüello: 2 首
# Doug Anderson: 2 首
# Danielle Chapman: 2 首
# Kevin Griffith: 2 首
# Shirley Buettner: 2 首
# Karin Gottshall: 2 首
# Rodney Torreson: 2 首
# Mary Ann Hoberman: 2 首
# John Updike: 2 首
# George Chapman: 2 首
# Thomas Chatterton: 2 首
# Oliver Goldsmith: 2 首
# T. E. Hulme: 2 首
# Joyce Kilmer: 2 首
# Thomas Nashe: 2 首
# Coventry Patmore: 2 首
# Robert Southwell SJ: 2 首
# James Thomson: 2 首
# Charles Dickens: 2 首
# Abraham Lincoln: 2 首
# Philip Freneau: 2 首
# Deborah Digges: 2 首
# Virginia Hamilton Adair: 2 首
# Ernesto Cardenal: 2 首
# John Crowe Ransom: 2 首
# Kamau Brathwaite: 2 首
# Lola Haskins: 2 首
# August Kleinzahler: 2 首
# James McKean: 2 首
# David Tucker: 2 首
# Bill Holm: 2 首
# Pam Rehm: 2 首
# Lance Larsen: 2 首
# Susan Browne: 2 首
# Moira Egan: 2 首
# Ruth Moose: 2 首
# Robert West: 2 首
# Joseph Stanton: 2 首
# Anne Pierson Wiese: 2 首
# Todd Davis: 2 首
# Leslie Scalapino: 2 首
# Tennessee Williams: 2 首
# Steven Orlen: 2 首
# Anne Killigrew: 2 首
# Lucretius: 2 首
# Dante Alighieri: 2 首
# Ovid: 2 首
# Matthew Prior: 2 首
# Ephelia: 2 首
# Peter Sacks: 2 首
# Frank Steele: 2 首
# Saadi Youssef: 2 首
# R. S. Gwynn: 2 首
# Ann Struthers: 2 首
# Shirley Kaufman: 2 首
# George Arnold: 2 首
# Melissa Kwasny: 2 首
# Catherine Imbriglio: 2 首
# Gary Dop: 2 首
# Dan Chiasson: 2 首
# Susan Hutton: 2 首
# Helen Maria Williams: 2 首
# Helen Leigh: 2 首
# Hannah More: 2 首
# Matilda Bethem: 2 首
# Elizabeth Moody: 2 首
# Amelia Opie: 2 首
# Anne Hunter: 2 首
# Christian Milne: 2 首
# Eliza Lee Follen: 2 首
# Elizabeth Akers Allen: 2 首
# Ina Coolbrith: 2 首
# Josephine Delphine Henderson Heard: 2 首
# Emily Pauline Johnson: 2 首
# Chris Forhan: 2 首
# Cecilia Woloch: 2 首
# Richard Barnfield: 2 首
# James Edwin Campbell: 2 首
# George Marion McClellan: 2 首
# James Ephraim McGirt: 2 首
# Joshua McCarter Simpson: 2 首
# Alfred Islay Walden: 2 首
# J. D. McClatchy: 2 首
# Tony Barnstone: 2 首
# William Waring Cuney: 2 首
# Mark Nickels: 2 首
# George Garrett: 2 首
# Nora Naranjo-Morse: 2 首
# Margo Tamez: 2 首
# Sara Littlecrow-Russell: 2 首
# Bhanu Kapil: 2 首
# Benjamin S. Grossberg: 2 首
# Tom Healy: 2 首
# Lee Ann Roripaugh: 2 首
# Brenda Iijima: 2 首
# Mark Turcotte: 2 首
# Diana García: 2 首
# James Joyce: 2 首
# Walter Clyde Curry: 2 首
# Henry Taylor: 2 首
# Brian Turner: 2 首
# Jennifer Tonge: 2 首
# Jacques Réda: 2 首
# Philip Gross: 2 首
# Tom Disch: 2 首
# Robert Fanning: 2 首
# Katherine Larson: 2 首
# Rebecca Hoogs: 2 首
# Maurice Manning: 2 首
# Nicole Pekarske: 2 首
# Neil Fischer: 2 首
# Alda Merini: 2 首
# Patrizia Cavalli: 2 首
# Umberto Fiori: 2 首
# Antonella Anedda: 2 首
# Valerio Magrelli: 2 首
# Fabio Pusterla: 2 首
# Patrizia Valduga: 2 首
# Jeffrey Schultz: 2 首
# Molly McQuade: 2 首
# Karl Kirchwey: 2 首
# Håkan Sandell: 2 首
# Jean Follain: 2 首
# Ibn Al-`Arabi: 2 首
# César Vallejo: 2 首
# Pura López-Colomé: 2 首
# Avot Yeshurun: 2 首
# Cathy Park Hong: 2 首
# Glyn Maxwell: 2 首
# Leila Wilson: 2 首
# Michael Rutherglen: 2 首
# Caki Wilkinson: 2 首
# Alison Stine: 2 首
# Sarah Barber: 2 首
# Leslie Williams: 2 首
# Dave Lucas: 2 首
# Katy Didden: 2 首
# Dahlia Ravikovitch: 2 首
# Álvaro de Campos: 2 首
# Timothy Murphy: 2 首
# John Poch: 2 首
# Jordan Davis: 2 首
# Belle Randall: 2 首
# Joseph Spece: 2 首
# Carlo Betocchi: 2 首
# Anne Brontë: 2 首
# George Eliot: 2 首
# Margaret Widdemer: 2 首
# Peter Bethanis: 2 首
# James Scruton: 2 首
# Mary Oliver: 2 首
# Jeanne Murray Walker: 2 首
# Merrill Moore: 2 首
# William Jay Smith: 2 首
# Michelle Menting: 1 首
# Lucia Cherciu: 1 首
# January Gill O'Neil: 1 首
# Sarah White: 1 首
# Kelly Madigan: 1 首
# P. Ivan Young: 1 首
# Amanda Nadelberg: 1 首
# Sunnylyn Thibodeaux: 1 首
# Sara Deniz Akant: 1 首
# Craig Morgan Teicher: 1 首
# JoAnn Balingit: 1 首
# Martin Carter: 1 首
# Jennifer Rahim: 1 首
# erica lewis: 1 首
# Vincent Katz: 1 首
# Jill Magi: 1 首
# Carmen Bernier-Grand: 1 首
# Christine Stewart-Nuñez: 1 首
# Brenda Coultas: 1 首
# Marie Buck: 1 首
# Ben Fama: 1 首
# Eleni Sikelianos: 1 首
# David Shook: 1 首
# Jennifer Firestone: 1 首
# Kit Robinson: 1 首
# Kenyatta Rogers: 1 首
# Jeff Derksen: 1 首
# Melvin Dixon: 1 首
# Anthony Carelli: 1 首
# Yehudah Halevi: 1 首
# Moses ibn Ezra: 1 首
# Anna Marie Sewell: 1 首
# Ryo Yamaguchi: 1 首
# Daniel Poppick: 1 首
# Carrie Olivia Adams: 1 首
# Emily Hunt: 1 首
# Laura Marie Marciano: 1 首
# Alan Felsenthal: 1 首
# Gwen Nell Westerman: 1 首
# Nick Arnold: 1 首
# Tatiana de la Tierra: 1 首
# Marilyn Dumont: 1 首
# Sandra Simpson: 1 首
# Dag T. Straumsvåg: 1 首
# Bridget Talone: 1 首
# Claudia La Rocco: 1 首
# Celina Su: 1 首
# Sophia Dahlin: 1 首
# Adrian Koesters: 1 首
# Kim Lozano: 1 首
# Toby Altman: 1 首
# Ali Power: 1 首
# Edmund Berrigan: 1 首
# Lisa Wells: 1 首
# Steve Sanfield: 1 首
# G. Maria Hindmarch: 1 首
# Tongo Eisen-Martin: 1 首
# Kim Parko: 1 首
# Gabriel Ojeda-Sague: 1 首
# Sally Van Doren: 1 首
# Ryler Dustin: 1 首
# Nancy Miller Gomez: 1 首
# Larry Neal: 1 首
# Stephanie Ellis Schlaifer: 1 首
# Dante Di Stefano: 1 首
# Judith Askew: 1 首
# Richard Robbins: 1 首
# Anne Sexton: 1 首
# bell hooks: 1 首
# Liz Ahl: 1 首
# Elisa Gabbert: 1 首
# Richard Jarrette: 1 首
# Max Garland: 1 首
# Jay Besemer: 1 首
# Paul Martin: 1 首
# Brian Lucas: 1 首
# Jessica Laser: 1 首
# Chris Martin: 1 首
# Peg Duthie: 1 首
# Kenneth Lee: 1 首
# Peter Schneider: 1 首
# Callie Garnett: 1 首
# Ginger Ko: 1 首
# Jasmine Gibson: 1 首
# Katy Bohinc: 1 首
# Chris Glomski: 1 首
# Michael Lally: 1 首
# Bruce Pemberton: 1 首
# André Naffis-Sahely: 1 首
# Austin Smith: 1 首
# Geoffrey Hilsabeck: 1 首
# Jared Stanley: 1 首
# Maureen Thorson: 1 首
# Matthew Olzmann: 1 首
# Kirsten Ihns: 1 首
# Megan Arlett: 1 首
# Francis Scott Key: 1 首
# William Langland: 1 首
# Gerald Fleming: 1 首
# Joan Retallack: 1 首
# Jena Osman: 1 首
# Mohja Kahf: 1 首
# Samuel Hazo: 1 首
# David Elliott: 1 首
# Betsy Franco: 1 首
# Leslie Bulion: 1 首
# Frannie Lindsay: 1 首
# Steven Herrick: 1 首
# Ralph Fletcher: 1 首
# Nathaniel Perry: 1 首
# Lois Beebe Hayna: 1 首
# Joan Larkin: 1 首
# Marjorie Maddox: 1 首
# Jocelyn Saidenberg: 1 首
# Jackson Mac Low: 1 首
# Justin Chin: 1 首
# Michelle Tea: 1 首
# Robert Glück: 1 首
# Maureen Seaton: 1 首
# John Cage: 1 首
# Wayne Koestenbaum: 1 首
# Brian Teare: 1 首
# Jenny Factor: 1 首
# Nathaniel Tarn: 1 首
# Fred Wah: 1 首
# Calef Brown: 1 首
# Ava Schicke: 1 首
# Rane Arroyo: 1 首
# Ronaldo V. Wilson: 1 首
# Joe Mills: 1 首
# Cathy Smith Bowers: 1 首
# Adrien Stoutenburg: 1 首
# Barbara Schmitz: 1 首
# Patricia Jabbeh Wesley: 1 首
# Marcus B. Christian: 1 首
# Angelo Giambra: 1 首
# E. A. Markham: 1 首
# Kathleen M. McCann: 1 首
# Kay Mullen: 1 首
# Ladan Osman: 1 首
# William Stanley Braithwaite: 1 首
# Ernest Dowson: 1 首
# Arthur O'Shaughnessy: 1 首
# Daniel Nyikos: 1 首
# Jorge Evans: 1 首
# David Black: 1 首
# Molly Fisk: 1 首
# Vivian Smith: 1 首
# Catherine Wing: 1 首
# Catherine Tufariello: 1 首
# Femi Osofisan: 1 首
# Lal Ded: 1 首
# Carol L. Gloor: 1 首
# Sarah A. Chavez: 1 首
# Jeanne Wagner: 1 首
# Carol Light: 1 首
# Jared Harél: 1 首
# Jillena Rose: 1 首
# Kathryn Stripling Byer: 1 首
# Laurel Blossom: 1 首
# David Sullivan: 1 首
# Julie Suk: 1 首
# Debra Wierenga: 1 首
# Shawn Pittard: 1 首
# Daniel J. Langton: 1 首
# Geraldine Connolly: 1 首
# Judson Mitcham: 1 首
# Quincy Troupe: 1 首
# Laynie Browne: 1 首
# James Sloan Gibbons: 1 首
# Derek N. Otsuji: 1 首
# Susan Kolodny: 1 首
# Ethel Lynn Beers: 1 首
# Casey Pycior: 1 首
# Richard M. Berlin: 1 首
# Bill Dodds: 1 首
# Joyce Armor: 1 首
# Mark Sanders: 1 首
# Lynne Sharon Schwartz: 1 首
# Patricia Clark: 1 首
# Maureen Ash: 1 首
# Laura Dimmit: 1 首
# Robin Chapman: 1 首
# Carolyn Creedon: 1 首
# Helen T. Glenn: 1 首
# Marie Thurmer: 1 首
# Gabriel Welsch: 1 首
# Mary M. Brown: 1 首
# Mo H. Saidi: 1 首
# Jay Leeming: 1 首
# Kathleen Driskell: 1 首
# Nancy Simpson: 1 首
# Kim Dower: 1 首
# Karla Huston: 1 首
# William Jolliff: 1 首
# Catherine Savage Brosman: 1 首
# Frank Osen: 1 首
# Ivan Hobson: 1 首
# Mark Kraushaar: 1 首
# Shari Wagner: 1 首
# Heather Allen: 1 首
# Karina Borowicz: 1 首
# Linda M. Hasselstrom: 1 首
# Matt Mason: 1 首
# Jackie Fox: 1 首
# Marty Walsh: 1 首
# Carol Ann Duffy: 1 首
# Robert Alter: 1 首
# Paul Celan: 1 首
# Ford Madox Ford: 1 首
# Jessie Pope: 1 首
# Eleanor Farjeon: 1 首
# Henry Newbolt: 1 首
# Patrick Shaw-Stewart: 1 首
# Mary Borden: 1 首
# Florence Ripley Mastin: 1 首
# Hervey Allen: 1 首
# Francis Ledwidge: 1 首
# Jennifer Maier: 1 首
# Mary Avidano: 1 首
# Roger Pfingston: 1 首
# Danusha Laméris: 1 首
# Barbara Ellen Sorensen: 1 首
# Karen J. Weyant: 1 首
# Amanda Strand: 1 首
# Penny Harter: 1 首
# Eric Chock: 1 首
# Kyle Harvey: 1 首
# Patrick Hicks: 1 首
# Angela de Hoyos: 1 首
# John Mason Neale: 1 首
# Amber Atiya: 1 首
# Kevin Killian: 1 首
# D. R. Goodman: 1 首
# Oli Hazzard: 1 首
# John Sakkis: 1 首
# Matthew Shenoda: 1 首
# Twyla Hansen: 1 首
# Octavio Paz: 1 首
# Debra Marquart: 1 首
# Timothy Tocher: 1 首
# Christine Lynn Mahoney: 1 首
# Mary Atkinson: 1 首
# JonArno Lawson: 1 首
# Nancy Bo Flood: 1 首
# Antonio Machado: 1 首
# Jen Bryant: 1 首
# Arden Levine: 1 首
# Cynthia Ventresca: 1 首
# Pat Emile: 1 首
# Ginger Murchison: 1 首
# Sylvia Ross: 1 首
# Nick Norwood: 1 首
# Eloise Greenfield: 1 首
# Taylor Mali: 1 首
# Lillian-Yvonne Bertram: 1 首
# Robert Francis: 1 首
# Jo'lene Dailey: 1 首
# Emilie Buchwald: 1 首
# Stephen Swinburne: 1 首
# Karen Jo Shapiro: 1 首
# Larry Eigner: 1 首
# Susan Rothbard: 1 首
# Robert Tremmel: 1 首
# Michael Lauchlan: 1 首
# Jack Cooper: 1 首
# Gary Whited: 1 首
# Eric Amling: 1 首
# Eiléan Ní Chuilleanáin: 1 首
# Diane Lockward: 1 首
# D. Gilson: 1 首
# Lynne Thompson: 1 首
# Lucy Tunstall: 1 首
# Kate Potts: 1 首
# Moniza Alvi: 1 首
# Ruth Wiggins: 1 首
# Fran Lock: 1 首
# Denise Riley: 1 首
# Jacqueline Jones LaMon: 1 首
# Bettina M. Walker: 1 首
# Cheryl Boyce-Taylor: 1 首
# Bryan Thao Worra: 1 首
# Brandon Som: 1 首
# Gerald Maa: 1 首
# Dana Roeser: 1 首
# Ricardo Alberto Maldonado: 1 首
# Karl O'Hanlon: 1 首
# Andrew McMillan: 1 首
# Ian Pople: 1 首
# Tyler Mills: 1 首
# Vidyan Ravinthiran: 1 首
# Paul Hostovsky: 1 首
# Ed Skoog: 1 首
# Kate Farrell: 1 首
# Marcus Slease: 1 首
# Jalal al-Din Rumi: 1 首
# Donald Platt: 1 首
# Monica Sok: 1 首
# Angie Macri: 1 首
# Igor Klikovac: 1 首
# Liz Howard: 1 首
# Dani Couture: 1 首
# Michael Prior: 1 首
# Jeff Latosik: 1 首
# Sachiko Murakami: 1 首
# Daniel Scott Tysdal: 1 首
# Shane Book: 1 首
# Nyla Matuk: 1 首
# Sonnet L'Abbé: 1 首
# Christopher Spaide: 1 首
# Mario Chard: 1 首
# Sean O’Brien: 1 首
# Jamie McKendrick: 1 首
# Paul Batchelor: 1 首
# Anna Jackson: 1 首
# Michele Leggott: 1 首
# Kate Camp: 1 首
# Jessie Puru: 1 首
# Tayi Tibble: 1 首
# Hera Lindsay Bird: 1 首
# Kerrin P. Sharpe: 1 首
# James Brown: 1 首
# Jenny Bornholdt: 1 首
# Anne Kennedy: 1 首
# Bernadette Hall: 1 首
# Vincent O’Sullivan: 1 首
# C. K. Stead: 1 首
# Tim Upperton: 1 首
# Chris Tse: 1 首
# Ashleigh Young: 1 首
# Faith Wilson: 1 首
# Steven Toussaint: 1 首
# Albert Wendt: 1 首
# Erik Kennedy: 1 首
# Therese Lloyd: 1 首
# Essa Ranapiri: 1 首
# Murray Edmond: 1 首
# Dylan Horrocks: 1 首
# Anahera Gildea: 1 首
# Courtney Sina Meredith: 1 首
# Martha Silano: 1 首
# Nathan Spoon: 1 首
# Chase Berggrun: 1 首
# Philip Good: 1 首
# Noah Baldino: 1 首
# Kristen Renee Miller: 1 首
# Aja Couchois Duncan: 1 首
# Ishmael Angaluuk Hope: 1 首
# Jennifer Militello: 1 首
# Lynn Melnick: 1 首
# Tony Lopez: 1 首
# Yoko Ono: 1 首
# Virginia Keane: 1 首
# Carolina Ebeid: 1 首
# Jennifer Jean: 1 首
# Rebecca Ariel Porte: 1 首
# Nestor Gomez: 1 首
# Molly Brodak: 1 首
# Sarah Gridley: 1 首
# Clint Smith: 1 首
# Alan Pelaez Lopez: 1 首
# Roy White: 1 首
# torrin a. greathouse: 1 首
# Alice Miller: 1 首
# Frank Sherlock: 1 首
# Yanyi: 1 首
# Faylita Hicks: 1 首
# Tiana Clark: 1 首
# Justice Ameer: 1 首
# Julian Randall: 1 首
# Ali Liebegott: 1 首
# Luther Hughes: 1 首
# Nam Le: 1 首
# Mira Rosenthal: 1 首
# Kai Conradi: 1 首
# avery r. young: 1 首
# An Li: 1 首
# Stephen Ira: 1 首
# Willie Perdomo: 1 首
# Joy Ladin: 1 首
# Ching-In Chen: 1 首
# Kathy Fagan: 1 首
# Clodagh Beresford Dunne: 1 首
# Jennifer S. Flescher: 1 首
# Oliver Baez Bendorf: 1 首
# Chrissy Williams: 1 首
# Lieke Marsman: 1 首
# Jane Huffman: 1 首
# Kien Lam: 1 首
# Natasha Sajé: 1 首
# Ben Purkert: 1 首
# Angela Narciso Torres: 1 首
# Julia Kolchinsky Dasbach: 1 首
# Eloisa Amezcua: 1 首
# Patrick Durgin: 1 首
# Joshua Marie Wilkinson: 1 首
# Joshua Jennifer Espinoza: 1 首
# LaWanda Walters: 1 首
# Victoria Martinez: 1 首
# Ashanti Anderson: 1 首
# Edil Hassan: 1 首
# Sahar Muradi: 1 首
# Saaro Umar: 1 首
# Aria Aber: 1 首
# Afshan Shafi: 1 首
# Nadra Mabrouk: 1 首
# Sheena Raza Faisal: 1 首
# Leo Boix: 1 首
# Charif Shanahan: 1 首
# Martha Serpas: 1 首
# Anthony Anaxagorou: 1 首
# Emily Liebowitz: 1 首
# Lily Zhou: 1 首
# John Skoyles: 1 首
# Melissa Studdard: 1 首
# K Ming Chang: 1 首
# Tom Wayman: 1 首
# Dayna Patterson: 1 首
# Spencer Short: 1 首
# Khaty Xiong: 1 首
# Jim Johnstone: 1 首
# Jane Zwart: 1 首
# Anne Marie Rooney: 1 首
# Jasmine Elizabeth Smith: 1 首
# Kayleb Rae Candrilli: 1 首
# Austin Segrest: 1 首
# Melian Radu: 1 首
# Megan Denton Ray: 1 首
# Mary Biddinger: 1 首
# Cody Smith: 1 首
# Raymond Luczak: 1 首
# Julia Randall: 1 首
# Allan Johnston: 1 首
# Jack Conway: 1 首
# Andrea Cohen: 1 首
# Tim Bowling: 1 首
# James Arthur: 1 首
# Josh Wild: 1 首
# Juhan Liiv: 1 首
# Angelos Sikelianos: 1 首
# Claude Esteban: 1 首
# Abid B Al-Abras: 1 首
# Labid: 1 首
# Arseny Tarkovsky: 1 首
# Elena Shvarts: 1 首
# Ouyang Jianghe: 1 首
# Elsa von Freytag-Loringhoven: 1 首
# Dan Howell: 1 首
# John Rybicki: 1 首
# José Antonio Rodríguez: 1 首
# Paolo Febbraro: 1 首
# Eugene Dubnov: 1 首
# Paul Claudel: 1 首
# Jorge Luis Borges: 1 首
# Yosef Gikatilla: 1 首
# Yitzhak Luria: 1 首
# V. Penelope Pelizzon: 1 首
# David Lehman: 1 首
# Sean Hill: 1 首
# Cally Conan-Davies: 1 首
# Mike Puican: 1 首
# Kathleen Raine: 1 首
# Joan Hutton Landis: 1 首
# John De Stefano: 1 首
# Gail Wronsky: 1 首
# Nicholas Friedman: 1 首
# Sharon Dolin: 1 首
# Barbara Perez: 1 首
# Kelly Cherry: 1 首
# Ricardo Pau-Llosa: 1 首
# Joan Mitchell: 1 首
# Anthony Opal: 1 首
# Joanne Dominique Dwyer: 1 首
# Stephen Stepanchev: 1 首
# David Caplan: 1 首
# Michelle Boisseau: 1 首
# Seán Hewitt: 1 首
# Gowann: 1 首
# George Kalogeris: 1 首
# Maram Al-Massri: 1 首
# Ava Leavell Haymon: 1 首
# Katerina Rudcenkova: 1 首
# Stuart Mills: 1 首
# Henry Parland: 1 首
# Wong May: 1 首
# Szilárd Borbély: 1 首
# Julia Shipley: 1 首
# Gayle Danley: 1 首
# Wang Ping: 1 首
# Myra Sklarew: 1 首
# Liane Strauss: 1 首
# Vievee Francis: 1 首
# Jennifer Tamayo: 1 首
# Farid Matuk: 1 首
# Harry Mathews: 1 首
# Philip Fried: 1 首
# Catherine Field: 1 首
# francine j. harris: 1 首
# Leontia Flynn: 1 首
# Colette Bryce: 1 首
# Mir Mahfuz Ali: 1 首
# Matthew Francis: 1 首
# Hugo Williams: 1 首
# James Brookes: 1 首
# Sophie Collins: 1 首
# Martin Monahan: 1 首
# David Wheatley: 1 首
# John Greening: 1 首
# Claire Trévien: 1 首
# John Wilkinson: 1 首
# Lev Oborin: 1 首
# Jerzy Ficowski: 1 首
# Víctor Rodríguez Núñez: 1 首
# Seán Ó Ríordáin: 1 首
# Grigori Dashevsky: 1 首
# Seán Ó Coileáin: 1 首
# Rob Schlegel: 1 首
# Darrel Alejandro Holnes: 1 首
# Peter Heller: 1 首
# Christopher Robley: 1 首
# Wyatt Prunty: 1 首
# John Rodriguez: 1 首
# Tara Betts: 1 首
# Erez Bitton: 1 首
# Helen Hajnoczky: 1 首
# William Fuller: 1 首
# Tyler Ford: 1 首
# Alex-Quan Pham: 1 首
# Marla Miniano: 1 首
# Lily Cao: 1 首
# Nick Laird: 1 首
# Dean Browne: 1 首
# Cal Doyle: 1 首
# Roisin Kelly: 1 首
# Dave Lordan: 1 首
# Declan Ryan: 1 首
# Leanne O'Sullivan: 1 首
# Doireann Ní Ghríofa: 1 首
# Tara Bergin: 1 首
# Aifric Mac Aodha: 1 首
# Martin Dyar: 1 首
# John McAuliffe: 1 首
# Michael McKimm: 1 首
# Caoilinn Hughes: 1 首
# Stephen Connolly: 1 首
# Miriam Gamble: 1 首
# Eleanor Hooker: 1 首
# Corey Mesler: 1 首
# Matt Hart: 1 首
# Catherine Staples: 1 首
# Luis Chaves: 1 首
# Primo Levi: 1 首
# Patrick Rosal: 1 首
# Paula Cunningham: 1 首
# Jeffrey Skinner: 1 首
# Zaffar Kunial: 1 首
# Simon Barraclough: 1 首
# Helen Mort: 1 首
# Daljit Nagra: 1 首
# Graham Mort: 1 首
# Robert Lax: 1 首
# Ailish Hopper: 1 首
# Laren McClung: 1 首
# Mary Morris: 1 首
# Margaret Noodin: 1 首
# Lilace Mellin Guignard: 1 首
# Joan Kane: 1 首
# Truth Thomas: 1 首
# Stephen Derwent Partington: 1 首
# Angélica Freitas: 1 首
# Kathy Engel: 1 首
# LeConté Dill: 1 首
# Rachael Allen: 1 首
# Kathi Wolfe: 1 首
# Kyle Dargan: 1 首
# John Murillo: 1 首
# Dante Micheaux: 1 首
# Denise Bergman: 1 首
# James Reidel: 1 首
# Felix Bernstein: 1 首
# Alec Finlay: 1 首
# Jennifer Bartlett: 1 首
# Regie Cabico: 1 首
# Dominique Christina: 1 首
# Bonny Cassidy: 1 首
# Cassie Lewis: 1 首
# Fiona Hile: 1 首
# Robbie Coburn: 1 首
# Claire Potter: 1 首
# Petra White: 1 首
# Susan Fealy: 1 首
# Michael Brennan: 1 首
# Lisa Gorton: 1 首
# Lionel G. Fogarty: 1 首
# Heather Phillipson: 1 首
# Sinéad Morrissey: 1 首
# León Salvatierra: 1 首
# John Maucere: 1 首
# Noah Buchholz: 1 首
# Jacques Darras: 1 首
# Haji Khavari: 1 首
# Miri Ben-Simhon: 1 首
# Uladzimir Niakliaeu: 1 首
# A. M. Juster: 1 首
# Fabián Severo: 1 首
# Julia Fiedorczuk: 1 首
# Teresia Teaiwa: 1 首
# No‘u Revilla: 1 首
# Emelihter Kihleng: 1 首
# Tui Scanlan: 1 首
# Lehua M. Taitano: 1 首
# Brandy Nālani McDougall: 1 首
# Hinemoana Baker: 1 首
# R.A. Villanueva: 1 首
# Tina Boyer Brown: 1 首
# Zilka Joseph: 1 首
# Melissa Range: 1 首
# Gary Barwin: 1 首
# Henry Gould: 1 首
# Patrick Cotter: 1 首
# Yuki Tanaka: 1 首
# Kerri Webster: 1 首
# Drew Swinger: 1 首
# Brendan Galvin: 1 首
# Benjamin Goldberg: 1 首
# Michelle Mitchell-Foust: 1 首
# Liz Countryman: 1 首
# Leslie McGrath: 1 首
# Ahren Warner: 1 首
# Samuel Amadon: 1 首
# Jos Charles: 1 首
# Elizabeth-Jane Burnett: 1 首
# Kirill Medvedev: 1 首
# Tommy Pico: 1 首
# Iain Britton: 1 首
# Valerie Duff: 1 首
# Diane Seuss: 1 首
# Al Young: 1 首
# Asia Calcagno: 1 首
# Natalie Rose Richardson: 1 首
# Malika Booker: 1 首
# Yona Harvey: 1 首
# Rachel Blau DuPlessis: 1 首
# Samuel Ace: 1 首
# Rodney Gomez: 1 首
# Sawnie Morris: 1 首
# Momina Mela: 1 首
# Yone Noguchi: 1 首
# Marnie Walsh: 1 首
# Leonard E. Nathan: 1 首
# Karma Larsen: 1 首
# Georgiana Cohen: 1 首
# Andrei Guruianu: 1 首
# Janet McCann: 1 首
# Jean L. Connor: 1 首
# Edwin Gladding Burrows: 1 首
# Martin Walls: 1 首
# Stephen Vincent Benét: 1 首
# Henry Carey: 1 首
# Arthur Hugh Clough: 1 首
# George Crabbe: 1 首
# Daniel Defoe: 1 首
# John Lydgate: 1 首
# J. M. Synge: 1 首
# Oscar Wilde: 1 首
# George Wither: 1 首
# Angela Shaw: 1 首
# Katy Giebenhain: 1 首
# Nancy McCleery: 1 首
# Gloria g. Murray: 1 首
# J. Lorraine Brown: 1 首
# Sarah Helen Whitman: 1 首
# Shirley Geok-Lin Lim: 1 首
# N. Scott Momaday: 1 首
# Dudley Randall: 1 首
# Pablo Antonio Cuadra: 1 首
# Brod Bagert: 1 首
# J. J. Bell: 1 首
# Eve Merriam: 1 首
# Bobbi Katz: 1 首
# Rowena Bastin Bennett: 1 首
# Dave Crawley: 1 首
# Joan Horton: 1 首
# Robert Pottle: 1 首
# Neal Levin: 1 首
# Chidiock Tichborne: 1 首
# Diane Thiel: 1 首
# Robert Penn Warren: 1 首
# David Bengtson: 1 首
# Miguel Hernández: 1 首
# David Kirby: 1 首
# Anne Caston: 1 首
# Robert King: 1 首
# Blas Manuel De Luna: 1 首
# Richard Siken: 1 首
# Grace Bauer: 1 首
# Gjertrud Schnackenberg: 1 首
# Ruth L. Schwartz: 1 首
# Julia Kasdorf: 1 首
# Keith Althaus: 1 首
# Anne Carson: 1 首
# Izumi Shikibu: 1 首
# Hadewijch II: 1 首
# Basho: 1 首
# Uvavnuk: 1 首
# Robert Bringhurst: 1 首
# Albert Garcia: 1 首
# Lita Hooper: 1 首
# Alex Phillips: 1 首
# Jeff Vande Zande: 1 首
# Dale Ritterbusch: 1 首
# Tania Rochelle: 1 首
# Marci Ridlon: 1 首
# Christopher Chambers: 1 首
# Herbert Morris: 1 首
# Tatiana Ziglar: 1 首
# Floyd Skloot: 1 首
# Connie Deanovich: 1 首
# Sarah Manguso: 1 首
# Jason Schneiderman: 1 首
# Michael Waters: 1 首
# Leonard Gontarek: 1 首
# Robert Hershon: 1 首
# Jeffrey McDaniel: 1 首
# Martha Ronk: 1 首
# Amber Flora Thomas: 1 首
#   Cynthia Rylant: 1 首
# Jane Whitledge: 1 首
# Rick Snyder: 1 首
# Judith Kitchen: 1 首
# Juliana Gray: 1 首
# Felecia Caton Garcia: 1 首
# Elizabeth Hobbs: 1 首
# Susan B. Anthony Somers-Willett: 1 首
# Roy Jacobstein: 1 首
# Nancy Botkin: 1 首
# Warren Woessner: 1 首
# Steven Cordova: 1 首
# Kim Noriega: 1 首
# Mike White: 1 首
# Joseph Ceravolo: 1 首
# Anne Porter: 1 首
# William Cole: 1 首
# Barry Goldensohn: 1 首
# Regina DeSalva: 1 首
# Peter Dale Scott: 1 首
# Kathleen Flenniken: 1 首
# Deborah Cummins: 1 首
# Steven Schneider: 1 首
# John Lyly: 1 首
# Thomas R. Smith: 1 首
# Jackson Wheeler: 1 首
# Mary Wollstonecraft Shelley: 1 首
# Sidney Lanier: 1 首
# Sir Edward Dyer: 1 首
# Omar Khayaam: 1 首
# Anacreon: 1 首
# Arthur Gorges: 1 首
# Solomon: 1 首
# William Cartwright: 1 首
# John Dowland: 1 首
# Giovanni Battista Guarini: 1 首
# Thomas Heywood: 1 首
# Meleager: 1 首
# Petrarch: 1 首
# Orlando Gibbons: 1 首
# Charles d'Orleans: 1 首
# Fitz-Greene Halleck: 1 首
# François Villon: 1 首
# Thomas Randolph: 1 首
# Tibullus: 1 首
# Gaius Petronius: 1 首
# Lady Grizel Baillie: 1 首
# Martha Baird: 1 首
# Mary Barber: 1 首
# Louisa S. Bevington: 1 首
# Mathilde Blind: 1 首
# Catherine Cockburn: 1 首
# Dinah Maria Craik: 1 首
# Mary Carolyn Davies: 1 首
# Sarah Dixon: 1 首
# Dorothea Du Bois: 1 首
# Lady Catherine Dyer: 1 首
# Catherine Maria Fanshawe: 1 首
# George Peele: 1 首
# Thomas Lodge: 1 首
# Æmilia Lanyer: 1 首
# John Fletcher: 1 首
# Abraham Cowley: 1 首
# William Kloefkorn: 1 首
# Lee McCarthy: 1 首
# Steven Huff: 1 首
# Trish Dugger: 1 首
# R. S. Thomas: 1 首
# Jonathan Holden: 1 首
# Richard Hoffman: 1 首
# Maxine Scates: 1 首
# Max Mendelsohn: 1 首
# Ellen Bass: 1 首
# Sharmila Voorakkara: 1 首
# Mary-Sherman Willis: 1 首
# Rick Campbell: 1 首
# Veronica Patterson: 1 首
# Joelle Biele: 1 首
# Berwyn Moore: 1 首
# Emmett Tenorio Melendez: 1 首
# William Ernest Henley: 1 首
# Rebecca Dunham: 1 首
# Lisa Fishman: 1 首
# Kaelum Poulson: 1 首
# John Maloney: 1 首
# Oni Buchanan: 1 首
# James Lenfestey: 1 首
# Dan Lechay: 1 首
# Mark Young: 1 首
# Cecil Touchon: 1 首
# Elizabeth Bentley: 1 首
# Ann Yearsley: 1 首
# Anna Dodsworth: 1 首
# Elizabeth Kirkham Mathews: 1 首
# Felicia Dorothea Hemans: 1 首
# Russell Libby: 1 首
# Conrad Hilberry: 1 首
# José Angel Araguz: 1 首
# Caroline Gilman: 1 首
# Penina Moise: 1 首
# Rebekah Gumpert Hyneman: 1 首
# Rose Terry Cooke: 1 首
# Sarah C. Woolsey: 1 首
# Eleanor Percy Lee: 1 首
# Zozan Hawez: 1 首
# Kathleen Fraser: 1 首
# Sarah Louisa Forten: 1 首
# Matthew Vetter: 1 首
# Mary Collier: 1 首
# Sebastian Matthews: 1 首
# Warren Hastings: 1 首
# Thomas Morris: 1 首
# Mary Jones: 1 首
# Thomas Middleton: 1 首
# Lord Edward, Lord Herbert of Cherbury: 1 首
# Matthew Green: 1 首
# Elizabeth Skurnick: 1 首
# Robert Charles O’Hara Benjamin: 1 首
# Joseph Seamon Cotter Sr.: 1 首
# Daniel Webster Davis: 1 首
# Timothy Thomas Fortune: 1 首
# Charlotte L. Forten Grimké: 1 首
# Joseph Cephas Holly: 1 首
# Adah Isaacs Menken: 1 首
# Ann Plato: 1 首
# James Monroe Whitfield: 1 首
# Albery Allson Whitman: 1 首
# Tu Fu: 1 首
# Peter O’Leary: 1 首
# Jessie B. Rittenhouse: 1 首
# Hittan of Tayyi: 1 首
# Elinor Maxwell: 1 首
# Sir Ronald Ross: 1 首
# Will Allen Dromgoole: 1 首
# Elizabeth Lincoln Otis: 1 首
# D. A. Ellsworth: 1 首
# William Makepeace Thackeray: 1 首
# Anne Marie Macari: 1 首
# Regan Huff: 1 首
# Judy Loest: 1 首
# Deborah Warren: 1 首
# Joseph Stroud: 1 首
# Coleman Barks: 1 首
# Alexandra Teague: 1 首
# Margaret Kaufman: 1 首
# Ronald Wallace: 1 首
# Ernest Hilbert: 1 首
# Sholeh Wolpé: 1 首
# Michelle Bennett: 1 首
# Julie Sheehan: 1 首
# E. Ethelbert Miller: 1 首
# Kenneth Carroll: 1 首
# Essex Hemphill: 1 首
# Reb Livingston: 1 首
# A. B. Spellman: 1 首
# Elizabeth Klise von Zerneck: 1 首
# Trish Crapo: 1 首
# Ben Vogt: 1 首
# Jean Ingelow: 1 首
# Lyn Lifshin: 1 首
# Nancyrose Houston: 1 首
# Lucille Lang Day: 1 首
# Jeff Worley: 1 首
# Dana Bisignani: 1 首
# Sherwin Bitsui: 1 首
# Christopher Gilbert: 1 首
# Susan Meyers: 1 首
# Peter Cooley: 1 首
# Carolyn Miller: 1 首
# Jan Mordenski: 1 首
# Kerri Sonnenberg: 1 首
# Patricia Frolander: 1 首
# Louis Jenkins: 1 首
# Meredith Holmes: 1 首
# Daniel Bailey: 1 首
# Donal Heffernan: 1 首
# John Straley: 1 首
# Duane Niatum: 1 首
# Marilyn Kallet: 1 首
# Tony Gloeggler: 1 首
# Kate Northrop: 1 首
# Laurence Hope: 1 首
# Carl Little: 1 首
# Aharon Shabtai: 1 首
# Qwo-Li Driskill: 1 首
# Michelle Y. Burke: 1 首
# Charlotte Elizabeth Tonna: 1 首
# Jean Blewett: 1 首
# Countee Cullen: 1 首
# Alec Brock Stevenson: 1 首
# Liz Rosenberg: 1 首
# Mark Smith-Soto: 1 首
# Katie Cappello: 1 首
# Kevin Goodan: 1 首
# Stephen Behrendt: 1 首
# Christopher Todd Matthews: 1 首
# Su Tung-Po: 1 首
# Helen Hoyt: 1 首
# Ludvig Holstein: 1 首
# Malcolm Cowley: 1 首
# Stephen Kuusisto: 1 首
# Katharine Auchincloss Lorr: 1 首
# Theodore Deppe: 1 首
# Zehra Çirac: 1 首
# Hans Magnus Enzensberger: 1 首
# Robert Gernhardt: 1 首
# Sarah Kirsch: 1 首
# Barbara Köhler: 1 首
# Oskar Pastior: 1 首
# Joachim Sartorius: 1 首
# Henry M. Seiden: 1 首
# Kevin Cantwell: 1 首
# Paula Tatarunis: 1 首
# Susan Donnelly: 1 首
# Dennis O'Driscoll: 1 首
# Jack Stewart: 1 首
# David Schloss: 1 首
# Maria Terrone: 1 首
# John Talbot: 1 首
# Jennifer O'Grady: 1 首
# Jason Gray: 1 首
# Matthew Brenneman: 1 首
# Michael Steffen: 1 首
# Elton Glaser: 1 首
# Ioanna Carlsen: 1 首
# Sara Backer: 1 首
# Greg Sellers: 1 首
# Bill Sweeney: 1 首
# Thorpe Moeckel: 1 首
# Bruce F. Murphy: 1 首
# Steven Cramer: 1 首
# William Walden: 1 首
# Christopher Logue: 1 首
# Piotr Sommer: 1 首
# Brian Barker: 1 首
# Rex Wilder: 1 首
# Dabney Stuart: 1 首
# Bill Coyle: 1 首
# Giovanni Pascoli: 1 首
# R. Parthasarathy: 1 首
# Hadrian: 1 首
# Kathleen Lynch: 1 首
# Reginald O'Hare Gibson: 1 首
# BJ Ward: 1 首
# Pierre Corneille: 1 首
# Lucas Howell: 1 首
# Laura Newbern: 1 首
# Medbh McGuckian: 1 首
# Theodore Worozbyt: 1 首
# Steven Heighton: 1 首
# Mary Rose O'Reilley: 1 首
# Coral Bracho: 1 首
# Ina Rousseau: 1 首
# Jin Eun-Young: 1 首
# Mary Kinzie: 1 首
# Vinda Karandikar: 1 首
# Shail D. Patel: 1 首
# Siobhán Campbell: 1 首
# Raffaello Baldini: 1 首
# Milo De Angelis: 1 首
# Franco Buffoni: 1 首
# Lisa Furmanski: 1 首
# Larissa Szporluk: 1 首
# Yannis Ritsos: 1 首
# Takashi Hiraide: 1 首
# Imru'al-qays: 1 首
# Waldo Williams: 1 首
# Giacomo Leopardi: 1 首
# Marko Vesović: 1 首
# Ramón López Velarde: 1 首
# Lydia Davis: 1 首
# Annette M'Baye: 1 首
# Tomas Venclova: 1 首
# Natan Zach: 1 首
# Yvonne Zipter: 1 首
# Philip White: 1 首
# Todd Hearon: 1 首
# Robin Behn: 1 首
# Stephen O’connor: 1 首
# Lesley Wheeler: 1 首
# Jorge Sánchez: 1 首
# mIEKAL aND: 1 首
# K. S. Ernst: 1 首
# Bob Dahlquist: 1 首
# Jesse Patrick Ferguson: 1 首
# Scott Helmes: 1 首
# Gustave Morin: 1 首
# jörg piringer: 1 首
# Philip Gallo: 1 首
# Michael Basinski: 1 首
# Glenn Morazzini: 1 首
# Dan Stryk: 1 首
# Virgil: 1 首
# Kevin C. Powers: 1 首
# Rhoda Janzen: 1 首
# Bruce Mackinnon: 1 首
# Aaron Poochigian: 1 首
# Chika Sagawa: 1 首
# Yoel Hoffmann: 1 首
# Yang Lian: 1 首
# Gabriel & Marcel Piqueray: 1 首
# Göran Sonnevi: 1 首
# Günter Eich: 1 首
# Mantinadologoi: 1 首
# Jules Supervielle: 1 首
# Mirza Asadullah Khan Ghalib: 1 首
# Patrick Dubost: 1 首
# Salwa Al-Neimi: 1 首
# Diakwain: 1 首
# Víctor Terán: 1 首
# Biddy Jenkinson: 1 首
# Friedrich Hölderlin: 1 首
# Richard Lehnert: 1 首
# Elisabeth Eybers: 1 首
# Robyn Sarah: 1 首
# Jason Labbe: 1 首
# Mel Nichols: 1 首
# Nada Gordon: 1 首
# Robert Fitterman: 1 首
# Kenneth Goldsmith: 1 首
# Craig Dworkin: 1 首
# Christian Bök: 1 首
# Kelle Groom: 1 首
# Colin Cheney: 1 首
# Emily Fragos: 1 首
# Kevin Prufer: 1 首
# William Hathaway: 1 首
# Chloe Honum: 1 首
# Patty Seyburn: 1 首
# Sam Willetts: 1 首
# Lavinia Greenlaw: 1 首
# D. H. Tracy: 1 首
# Robert P. Baird: 1 首
# Attilio Bertolucci: 1 首
# Talvikki Ansel: 1 首
# Jeramy Dodds: 1 首
# Larry Bradley: 1 首
# James Merrill: 1 首
# Lydia Maria Child: 1 首
# Eugene Field: 1 首
# Clement Clarke Moore: 1 首
# Charlotte Brontë: 1 首
# Mark Twain: 1 首
# Charles Tomlinson: 1 首
# Aileen Lucia Fisher: 1 首
# Ralph Bergengren: 1 首
# Harry Graham: 1 首
# Constance Levy: 1 首
# Kalli Dakos: 1 首
# Sarah Josepha Hale: 1 首
# Frank Asch: 1 首
# Grace Hazard Conkling: 1 首
# Helen Dudley: 1 首
# William Vaughn Moody: 1 首
# Lily A. Long: 1 首
# Charles Hanson Towne: 1 首
# Schuyler Van Rensselaer: 1 首
# Carole Bernstein: 1 首
# Ann Snodgrass: 1 首
# Lianne Spidel: 1 首
# Clarinda Harriss: 1 首
# Paul Zimmer: 1 首
# Robert B. Shaw: 1 首
# Maudelle Driskell: 1 首
# Judith Kroll: 1 首
# Richard Tillinghast: 1 首
# John Hazard: 1 首
# Hugh Seidman: 1 首
# Susan Hahn: 1 首
# Art Nahill: 1 首
# Marie-Claire Bancquart: 1 首
# Charles Juliet: 1 首
# Robert Marteau: 1 首
# Jacques Roubaud: 1 首
# Jeffrey Greene: 1 首
# Robert Pack: 1 首
# George Scarbrough: 1 首
# Eric Nelson: 1 首
# Paulann Petersen: 1 首
# Trevor West Knapp: 1 首
# Deirdre O'Connor: 1 首
# Catherine Sasanov: 1 首
# Alexa Selph: 1 首
# Chris Green: 1 首
# Al Maginnes: 1 首
# Brent Pallas: 1 首
# Francesca Abbate: 1 首
# Thomas Pfau: 1 首
# Alissa Leigh: 1 首
# Rich Murphy: 1 首
# Sharon Bryan: 1 首
# J. P. White: 1 首
# Ellen Hinsey: 1 首
# Alissa Valles: 1 首
# Mark Defoe: 1 首
# John Surowiecki: 1 首
# Daniel Groves: 1 首
# Susan Kinsolving: 1 首
# Kunst Judith McCune: 1 首
# Roger Mitchell: 1 首
# Paul Grant: 1 首
# Susan Rolston: 1 首
# Lisa Barnett: 1 首
# Ron De Maris: 1 首
# Melanie Almeder: 1 首
# Lynn Powell: 1 首
# Neisha Tweed: 1 首
# Stefi Weisburd: 1 首
# Alison Pelegrin: 1 首
# Ethan Stebbins: 1 首
# Mike Chasar: 1 首
# Kevin A. González: 1 首
# Dylan Thomas: 1 首
# Jim Carroll: 1 首
# Lew R. Sarett: 1 首
# Witter Bynner: 1 首
# John Wheelwright: 1 首
# R. P. Blackmur: 1 首
# Norman Macleod: 1 首

# %%
import json
from pathlib import Path

# SFT JSONL 文件路径
sft_path = Path("D:/桌面/DL/Pro/poetry_sft.jsonl")

print("=== 前 15 条 SFT 样本 ===\n")

with open(sft_path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        if i >= 15:
            break
        record = json.loads(line.strip())
        messages = record.get("messages", [])
        
        print(f"--- SFT 样本 {i+1} ---")
        for msg in messages:
            role = msg.get("role")
            content = msg.get("content")
            print(f"{role}: {content}\n")
        print("------------------------------\n")
# Out:
# === 前 15 条 SFT 样本 ===
#
# --- SFT 样本 1 ---
# user: Write a poem in the style of Michelle Menting.
#
# assistant: Dog bone, stapler,
# cribbage board, garlic press
#      because this window is loose—lacks
# suction, lacks grip.
# Bungee cord, bootstrap,
# dog leash, leather belt
#      because this window had sash cords.
# They frayed. They broke.
# Feather duster, thatch of straw, empty
# bottle of Elmer's glue
#      because this window is loud—its hinges clack
# open, clack shut.
# Stuffed bear, baby blanket,
# single crib newel
#      because this window is split. It's dividing
# in two.
# Velvet moss, sagebrush,
# willow branch, robin's wing
#      because this window, it's pane-less. It's only
# a frame of air.
#
# ------------------------------
#
# --- SFT 样本 2 ---
# user: Write a poem in the style of Lucia Cherciu.
#
# assistant: The old cupola glinted above the clouds, shone
# among fir trees, but it took him an hour
# for the half mile all the way up the hill. As he trailed,
# the village passed him by, greeted him,
# asked about his health, but everybody hurried
# to catch the mass, left him leaning against fences,
# measuring the road with the walking stick he sculpted.
# He yearned for the day when the new church
# would be built—right across the road. Now
# it rises above the moon: saints in frescoes
# meet the eye, and only the rain has started to cut
# through the shingles on the roof of his empty
# house. The apple trees have taken over the sky,
# sequestered the gate, sidled over the porch.
#
# ------------------------------
#
# --- SFT 样本 3 ---
# user: Write a poem in the style of Ted Kooser.
#
# assistant: Look for me under the hood
# of that old Chevrolet settled in weeds
# at the end of the pasture.
# I'm the radiator that spent its years
# bolted in front of an engine
# shoving me forward into the wind.
# Whatever was in me in those days
# has mostly leaked away,
# but my cap's still screwed on tight
# and I know the names of all these
# tattered moths and broken grasshoppers
# the rest of you've forgotten.
#
# ------------------------------
#
# --- SFT 样本 4 ---
# user: Write a poem in the style of Grace Cavalieri.
#
# assistant: Behind the silo, the Mother Rabbit
# hunches like a giant spider with strange calm:
# six tiny babies beneath, each
# clamoring for a sweet syringe of milk.
# This may sound cute to you, reading
# from your pulpit of plenty,
# but one small one was left out of reach,
# a knife of fur
# barging between the others.
# I watched behind a turret of sand. If
# I could have cautioned the mother rabbit
# I would. If I could summon the
# Bunnies to fit him in beneath
# the belly's swell
# I would. But instead, I stood frozen, wishing
# for some equity. This must be
# why it's called Wild Life because of all the
# crazed emotions tangled up in
# the underbrush within us.
# Did I tell you how
# the smallest one, black and trembling,
# hopped behind the kudzu
# still filigreed with wanting?
# Should we talk now of animal heritage, their species,
# creature development? And what do we say
# about form and focus—
# writing this when a stray goes hungry, and away.
#
# ------------------------------
#
# --- SFT 样本 5 ---
# user: Write a poem in the style of Connie Wanek.
#
# assistant: When I push your button
# you fly off the handle,
# old skin and bones,
# black bat wing.
# We're alike, you and I.
# Both of us
# resemble my mother,
# so fierce in her advocacy
# on behalf of
# the most vulnerable child
# who'll catch his death
# in this tempest.
# Such a headwind!
# Sometimes it requires
# all my strength
# just to end a line.
# But when the wind is at
# my back, we're likely
# to get carried away, and say
# something we can never retract,
# something saturated from the ribs
# down, an old stony
# word like ruin. You're what roof
# I have, frail thing,
# you're my argument
# against the whole sky.
# You're the fundamental difference
# between wet and dry.
#
# ------------------------------
#
# --- SFT 样本 6 ---
# user: Write a poem in the style of January Gill O'Neil.
#
# assistant: You are the start of the week
# or the end of it, and according
# to The Beatles you creep in
# like a nun. You're the second
# full day the kids have been
# away with their father, the second
# full day of an empty house.
# Sunday, I've missed you. I've been
# sitting in the backyard with a glass
# of Pinot waiting for your arrival.
# Did you know the first Sweet 100s
# are turning red in the garden,
# but the lettuce has grown
# too bitter to eat. I am looking
# up at the bluest sky I have ever seen,
# cerulean blue, a heaven sky
# no one would believe I was under.
# You are my witness. No day
# is promised. You are absolution.
# You are my unwritten to-do list,
# my dishes in the sink, my brownie
# breakfast, my braless day.
#
# ------------------------------
#
# --- SFT 样本 7 ---
# user: Write a poem using the theme: Living,Time & Brevity,Relationships,Family & Ancestors,Nature,Landscapes & Pastorals,Seas, Rivers, & Streams,Social Commentaries,History & Politics, in the style of Joy Harjo.
#
# assistant: Invisible fish swim this ghost ocean now described by waves of sand, by water-worn rock. Soon the fish will learn to walk. Then humans will come ashore and paint dreams on the dying stone. Then later, much later, the ocean floor will be punctuated by Chevy trucks, carrying the dreamers’ decendants, who are going to the store.
#
# ------------------------------
#
# --- SFT 样本 8 ---
# user: Write a poem using the theme: Religion,The Spiritual,Mythology & Folklore,Fairy-tales & Legends, in the style of Joy Harjo.
#
# assistant: Don’t bother the earth spirit who lives here. She is working on a story. It is the oldest story in the world and it is delicate, changing. If she sees you watching she will invite you in for coffee, give you warm bread, and you will be obligated to stay and listen. But this is no ordinary story. You will have to endure earthquakes, lightning, the deaths of all those you love, the most blinding beauty. It’s a story so compelling you may never want to leave; this is how she traps you. See that stone finger over there? That is the only one who ever escaped.
#
# ------------------------------
#
# --- SFT 样本 9 ---
# user: Write a poem in the style of John Ashbery.
#
# assistant: Is anything central?
# Orchards flung out on the land,
# Urban forests, rustic plantations, knee-high hills?
# Are place names central?
# Elm Grove, Adcock Corner, Story Book Farm?
# As they concur with a rush at eye level
# Beating themselves into eyes which have had enough
# Thank you, no more thank you.
# And they come on like scenery mingled with darkness
# The damp plains, overgrown suburbs,
# Places of known civic pride, of civil obscurity.
#
# These are connected to my version of America
# But the juice is elsewhere.
# This morning as I walked out of your room
# After breakfast crosshatched with
# Backward and forward glances, backward into light,
# Forward into unfamiliar light,
# Was it our doing, and was it
# The material, the lumber of life, or of lives
# We were measuring, counting?
# A mood soon to be forgotten
# In crossed girders of light, cool downtown shadow
# In this morning that has seized us again?
#
# I know that I braid too much on my own
# Snapped-off perceptions of things as they come to me.
# They are private and always will be.
# Where then are the private turns of event
# Destined to bloom later like golden chimes
# Released over a city from a highest tower?
# The quirky things that happen to me, and I tell you,
# And you know instantly what I mean?
# What remote orchard reached by winding roads
# Hides them? Where are these roots?
#
# It is the lumps and trials
# That tell us whether we shall be known
# And whether our fate can be exemplary, like a star.
# All the rest is waiting
# For a letter that never arrives,
# Day after day, the exasperation
# Until finally you have ripped it open not knowing what it is,
# The two envelope halves lying on a plate.
# The message was wise, and seemingly
# Dictated a long time ago, but its time has still
# Not arrived, telling of danger, and the mostly limited
# Steps that can be taken against danger
# Now and in the future, in cool yards,
# In quiet small houses in the country,
# Our country, in fenced areas, in cool shady streets.
#
# ------------------------------
#
# --- SFT 样本 10 ---
# user: Write a poem using the theme: Living,Parenthood,The Body,The Mind,Nature,Trees & Flowers, in the style of Simone White.
#
# assistant: Hour in which I consider hydrangea, a salt or sand plant, varietal, the question of varietals, the diet of every mother I know, 5 pounds feels like 20, I have lost … I have lost, yes, a sense of my own possible beauty, grown external, I externalize beauty. Beauty occurs on the surface of plants; the sun darkens the skin of my child, he is so small, he is beautiful (I can see; it is obvious) and everything about him is beautiful. His hand swells from the bite [spread?] of some insect[’s] venom because he is small. He appears to feel nothing. He smashes his skull against the floor. He screams. I hold him in my lap on the kitchen floor in front of an open freezer, pressing a pack of frozen clay against his forehead. He likes the cold. I see; it is so obvious. Hydrangea. When I move, when I walk pushing my child’s stroller (it is both walking and pushing or hauling, sometimes, also, lifting; it is having another body, an adjunct body composed of errand and weight and tenderness and no small amount of power), I imagine I can feel this small amount of weight, this 5 pounds like 20, interfering with the twitch of every muscle in my body. As an object, a mother is confusing, a middle-aged mother with little spare flesh, I feel every inch of major muscle pulling against gravity and against the weight of my child, now sleeping. This is the hour for thinking hydrangea. Let no man look at me. I stop to brush the drowsy child’s little eye. His face. He barely considers his mother. I am all around him. Why should he consider what is all around him? Perhaps what is missing is a subtle power of differentiation. I am in, therefore, a time of mass apprehensions.
#
# ------------------------------
#
# --- SFT 样本 11 ---
# user: Write a poem in the style of Heid E. Erdrich.
#
# assistant: She couldn't help but sting my finger,
# clinging a moment before I flung her
# to the ground. Her gold is true, not the trick
# evening light plays on my roses.
# She curls into herself, stinger twitching,
# gilt wings folded. Her whole life just a few weeks,
# and my pain subsided in a moment.
# In the cold, she hardly had her wits to buzz.
# No warning from either of us:
# she sleeping in the richness of those petals,
# then the hand, my hand, cupping the bloom
# in devastating force, crushing the petals for the scent.
# And she mortally threatened, wholly unaware
# that I do this daily, alone with the gold last light,
# in what seems to me an act of love.
#
# ------------------------------
#
# --- SFT 样本 12 ---
# user: Write a poem in the style of Sarah White.
#
# assistant: I will not speak ill of Jack Flick.
# I will rarely look
# at the scar he made on my cheek
# one summer at the lake.
# I won't speak ill of Jack whose freckles
# and gangly legs are gone.
# So is the drained face I saw when he saw
# what he'd done with a sharp rock
# nonchalantly skipped.
# I will speak well, for it was somewhat
# sweet to lie on the dock while Jack
# and his friends bent down
# and wiped my face with a sandy towel.
# I will speak well of them,
# for most are gone
# and the wound proved small.
# I will speak well, for the rock
# missed my eye. I can hardly find
# the scar. Jack went into the air
# corps, fought in one of the wars,
# retired, and lived less than a year
# before his tender heart gave out.
# I will speak well of Jack.
#
# ------------------------------
#
# --- SFT 样本 13 ---
# user: Write a poem in the style of Judith Harris.
#
# assistant: How quiet is the spruce,
# the wind twills
# through the uppermost tier
# of splayed leaves.
# Now the song of a bird
# like the squeaky lock
# over a canoe's oar,
# followed by startling chirps,
# the sky pushing its clouds
# like sailboats,
# and I think, what kind of God
# keeps himself secret
# so that to find him out
# we have to seek, as children do
# for something like the beetle
# scuttling between grass,
# hidden in plain sight.
#
# ------------------------------
#
# --- SFT 样本 14 ---
# user: Write a poem in the style of Kelly Madigan.
#
# assistant: You think we are the pointed argument,
# the man drunk at the party showing off
# his gun collection, the bed of nettles.
#
# What we really are is hidden from you:
# girl weeping in the closet among her stepfather's boots;
# tuft of rabbit fur caught in barbed wire; body of the baby
# in the landfill; boy with the shy mouth playing his guitar
# at the picnic table, out in the dirt yard.
#
# We slide into this world benign and pliable,
# quills pressed down smooth over back and tail.
# Only one hour here stiffens the barbs into thousands
# of quick retorts. Everything this well-guarded
# remembers being soft once.
#
# ------------------------------
#
# --- SFT 样本 15 ---
# user: Write a poem in the style of Cathryn Essinger.
#
# assistant: I planted an apple tree in memory
# of my mother, who is not gone,
#
# but whose memory has become
# so transparent that she remembers
#
# slicing apples with her grandmother
# (yellow apples; blue bowl) better than
#
# the fruit that I hand her today. Still,
# she polishes the surface with her thumb,
#
# holds it to the light and says with no
# hesitation, Oh, Yellow Transparent . . .
#  they're so fragile, you can almost seeto the core. She no longer remembers how
#
# to roll the crust, sweeten the sauce, but
# her desire is clear—it is pie that she wants.
#
# And so, I slice as close as I dare to the core—
# to that little cathedral to memory—where
#
# the seeds remember everything they need
# to know to become yellow and transparent.
#
# ------------------------------

# %%
import json
import torch
from pathlib import Path
from tokenizers import Tokenizer

# ---------------------------
# 本地 tokenizer
# ---------------------------
tokenizer_path = r"D:\桌面\课题\大模型\qwen2.5-7b\tokenizer.json"
tokenizer = Tokenizer.from_file(tokenizer_path)

# ---------------------------
# 读取 JSONL 的第一条样本
# ---------------------------
sft_path = Path(r"D:/桌面/DL/Pro/poetry_sft.jsonl")
with open(sft_path, "r", encoding="utf-8") as f:
    first_line = f.readline()
    sample_jsonl = json.loads(first_line.strip())

# ---------------------------
# 拼接 user 和 assistant
# ---------------------------
user_text = ""
assistant_text = ""

for msg in sample_jsonl.get("messages", []):
    if msg["role"] == "user":
        user_text += msg["content"].strip() + "\n"
    elif msg["role"] == "assistant":
        assistant_text += msg["content"].strip() + "\n"

full_text = user_text + assistant_text

# ---------------------------
# Tokenization
# ---------------------------
input_ids = tokenizer.encode(full_text).ids
user_len = len(tokenizer.encode(user_text).ids)

input_ids = torch.tensor(input_ids).unsqueeze(0)  # batch=1
labels = input_ids.clone()
labels[:, :user_len] = -100  # user 部分不计算 loss

# ---------------------------
# 假设你有一个本地 PyTorch LLM 模型（Qwen2.5-7b）
# model.forward 返回 logits (batch, seq_len, vocab_size)
# 这里演示如何计算 assistant loss
# ---------------------------

# logits 这里用随机张量模拟，实际用你本地模型前向
batch, seq_len = input_ids.shape
vocab_size = tokenizer.get_vocab_size()
logits = torch.randn(batch, seq_len, vocab_size)  # 模拟模型输出

# CrossEntropyLoss 计算
loss_fct = torch.nn.CrossEntropyLoss(ignore_index=-100)
loss = loss_fct(logits.view(-1, vocab_size), labels.view(-1))

print("=== 第一条样本 assistant loss ===")
print(loss.item())
# Out:
# === 第一条样本 assistant loss ===
# 12.38481330871582

# %%
# %%
import json
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from peft import LoraConfig, get_peft_model
import sentencepiece as spm  # 如果 tokenizer 是 spm

# -------------------------
# 配置
# -------------------------
CONFIG = {
    "model_path": r"D:/桌面/课题/大模型/qwen2.5-7b",
    "tokenizer_path": r"D:/桌面/课题/大模型/qwen2.5-7b/tokenizer.model",
    "data_path": r"D:/桌面/DL/Pro/poetry_sft.jsonl",
    "output_dir": r"D:/桌面/课题/大模型/qwen2.5-sft",
    "num_train_epochs": 3,
    "batch_size": 1,
    "learning_rate": 2e-5,
    "max_len": 1024,
    "device": "cuda" if torch.cuda.is_available() else "cpu",
}

# -------------------------
# 1. 加载 tokenizer（SentencePiece）
# -------------------------
sp = spm.SentencePieceProcessor()
sp.load(CONFIG["tokenizer_path"])

def tokenize(text, max_len=1024):
    ids = sp.encode(text, out_type=int)
    if len(ids) > max_len:
        ids = ids[:max_len]
    return ids

# -------------------------
# 2. 构建 Dataset
# -------------------------
class PoetryDataset(Dataset):
    def __init__(self, jsonl_path, tokenizer, max_len=1024):
        self.data = []
        self.tokenizer = tokenizer
        self.max_len = max_len
        with open(jsonl_path, "r", encoding="utf-8") as f:
            for line in f:
                self.data.append(json.loads(line))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        user_text = sample["messages"][0]["content"]
        assistant_text = sample["messages"][1]["content"]
        
        prompt = f"<|im_start|>user\n{user_text}<|im_end|>\n<|im_start|>assistant\n{assistant_text}<|im_end|>"
        input_ids = self.tokenizer(prompt, max_len=self.max_len)
        # user 部分 loss=-100
        user_len = len(self.tokenizer(f"<|im_start|>user\n{user_text}<|im_end|>\n", max_len=self.max_len))
        labels = input_ids.copy()
        labels[:user_len] = -100

        # padding
        if len(input_ids) < self.max_len:
            pad_len = self.max_len - len(input_ids)
            input_ids += [0]*pad_len
            labels += [-100]*pad_len

        return {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "labels": torch.tensor(labels, dtype=torch.long)
        }

dataset = PoetryDataset(CONFIG["data_path"], tokenize, CONFIG["max_len"])
loader = DataLoader(dataset, batch_size=CONFIG["batch_size"], shuffle=True)

# -------------------------
# 3. 加载 Qwen2.5-7B 模型
# -------------------------
# 这里假设你有官方 QwenForCausalLM 类
from qwen_model import QwenForCausalLM

model = QwenForCausalLM()
state_dict = torch.load(CONFIG["model_path"], map_location=CONFIG["device"])
model.load_state_dict(state_dict)
model.to(CONFIG["device"])
model.train()

# -------------------------
# 4. LoRA 配置
# -------------------------
lora_cfg = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=["q_proj","v_proj","k_proj","o_proj"],
    task_type="CAUSAL_LM"
)
model = get_peft_model(model, lora_cfg)

# -------------------------
# 5. Optimizer + Loss
# -------------------------
optimizer = torch.optim.AdamW(model.parameters(), lr=CONFIG["learning_rate"])
loss_fn = nn.CrossEntropyLoss(ignore_index=-100)

# -------------------------
# 6. 训练循环
# -------------------------
for epoch in range(CONFIG["num_train_epochs"]):
    total_loss = 0.0
    for batch in loader:
        optimizer.zero_grad()
        input_ids = batch["input_ids"].to(CONFIG["device"])
        labels = batch["labels"].to(CONFIG["device"])
        
        outputs = model(input_ids=input_ids)  # logits
        logits = outputs.logits
        loss = loss_fn(logits.view(-1, logits.size(-1)), labels.view(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1} 平均 loss: {total_loss/len(loader):.4f}")

# -------------------------
# 7. 保存 LoRA 模型
# -------------------------
model.save_pretrained(CONFIG["output_dir"])
# tokenizer 保存方法视你具体实现
sp.save(CONFIG["output_dir"] + "/tokenizer.model")
print("🎉 LoRA 微调完成！")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 7
#       4 import warnings
#       5 warnings.filterwarnings("ignore")
# ----> 7 from transformers import AutoModelForCausalLM
#       8 from peft import LoraConfig, get_peft_model
#      10 # -------------------------
#      11 # 配置
#      12 # -------------------------
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)     36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)     37     "pyyaml",
#      38 ]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\__init__.py:82
#      39 from .doc import (
#      40     add_code_sample_docstrings,
#      41     add_end_docstrings,
#    (...)     45     replace_return_docstrings,
#      46 )
#      47 from .generic import (
#      48     ContextManagers,
#      49     ExplicitEnum,
#    (...)     80     working_or_temp_dir,
#      81 )
# ---> 82 from .hub import (
#      83     CHAT_TEMPLATE_DIR,
#      84     CHAT_TEMPLATE_FILE,
#      85     CLOUDFRONT_DISTRIB_PREFIX,
#      86     HF_MODULES_CACHE,
#      87     HUGGINGFACE_CO_PREFIX,
#      88     HUGGINGFACE_CO_RESOLVE_ENDPOINT,
#      89     LEGACY_PROCESSOR_CHAT_TEMPLATE_FILE,
#      90     PYTORCH_PRETRAINED_BERT_CACHE,
#      91     PYTORCH_TRANSFORMERS_CACHE,
#      92     S3_BUCKET_PREFIX,
#      93     TRANSFORMERS_CACHE,
#      94     TRANSFORMERS_DYNAMIC_MODULE_NAME,
#      95     EntryNotFoundError,
#      96     PushInProgress,
#      97     PushToHubMixin,
#      98     RepositoryNotFoundError,
#      99     RevisionNotFoundError,
#     100     cached_file,
#     101     default_cache_path,
#     102     define_sagemaker_information,
#     103     download_url,
#     104     extract_commit_hash,
#     105     has_file,
#     106     http_user_agent,
#     107     is_offline_mode,
#     108     is_remote_url,
#     109     list_repo_templates,
#     110     try_to_load_from_cache,
#     111 )
#     112 from .import_utils import (
#     113     ACCELERATE_MIN_VERSION,
#     114     ENV_VARS_TRUE_AND_AUTO_VALUES,
#    (...)    277     torch_only_method,
#     278 )
#     279 from .peft_utils import (
#     280     ADAPTER_CONFIG_NAME,
#     281     ADAPTER_SAFE_WEIGHTS_NAME,
#    (...)    284     find_adapter_config_file,
#     285 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\utils\hub.py:32
#      30 import huggingface_hub
#      31 import requests
# ---> 32 from huggingface_hub import (
#      33     _CACHED_NO_EXIST,
#      34     CommitOperationAdd,
#      35     ModelCard,
#      36     ModelCardData,
#      37     constants,
#      38     create_branch,
#      39     create_commit,
#      40     create_repo,
#      41     hf_hub_download,
#      42     hf_hub_url,
#      43     list_repo_tree,
#      44     snapshot_download,
#      45     try_to_load_from_cache,
#      46 )
#      47 from huggingface_hub.file_download import REGEX_COMMIT_HASH, http_get
#      48 from huggingface_hub.utils import (
#      49     EntryNotFoundError,
#      50     GatedRepoError,
#    (...)     58     hf_raise_for_status,
#      59 )
#
# ImportError: cannot import name 'list_repo_tree' from 'huggingface_hub' (c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\__init__.py)
